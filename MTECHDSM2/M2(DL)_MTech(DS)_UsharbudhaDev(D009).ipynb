# %% [markdown]
# # TASK #2: MOUNT DRIVE AND IMPORT LIBRARIES/DATASETS

# %% [markdown]
# - In this case study, we want to classify images of traffic signs using deep Convolutional Neural Networks (CNNs).
# - The dataset consists of 43 different classes of images.
# - Classes are as listed below:
#   - 0 = Speed limit (20km/h)
#   - 1 = Speed limit (30km/h)
#   - 2 = Speed limit (50km/h)
#   - 3 = Speed limit (60km/h)
#   - 4 = Speed limit (70km/h)
#   - 5 = Speed limit (80km/h)
#   - 6 = End of speed limit (80km/h)
#   - 7 = Speed limit (100km/h)
#   - 8 = Speed limit (120km/h)
#   - 9 = No passing
#   - 10 = No passing for vehicles over 3.5 metric tons
#   - 11 = Right-of-way at the next intersection
#   - 12 = Priority road
#   - 13 = Yield
#   - 14 = Stop
#   - 15 = No vehicles
#   - 16 = Vehicles over 3.5 metric tons prohibited
#   - 17 = No entry
#   - 18 = General caution
#   - 19 = Dangerous curve to the left
#   - 20 = Dangerous curve to the right
#   - 21 = Double curve
#   - 22 = Bumpy road
#   - 23 = Slippery road
#   - 24 = Road narrows on the right
#   - 25 = Road work
#   - 26 = Traffic signals
#   - 27 = Pedestrians
#   - 28 = Children crossing
#   - 29 = Bicycles crossing
#   - 30 = Beware of ice/snow
#   - 31 = Wild animals crossing
#   - 32 = End of all speed and passing limits
#   - 33 = Turn right ahead
#   - 34 = Turn left ahead
#   - 35 = Ahead only
#   - 36 = Go straight or right
#   - 37 = Go straight or left
#   - 38 = Keep right
#   - 39 = Keep left
#   - 40 = Roundabout mandatory
#   - 41 = End of no passing
#   - 42 = End of no passing by vehicles over 3.5 metric tons
#
# - Citation
# J. Stallkamp, M. Schlipsing, J. Salmen, and C. Igel. The German Traffic Sign Recognition Benchmark: A multi-class classification competition. In Proceedings of the IEEE International Joint Conference on Neural Networks, pages 1453–1460. 2011.
# @inproceedings{Stallkamp-IJCNN-2011, author = {Johannes Stallkamp and Marc Schlipsing and Jan Salmen and Christian Igel}, booktitle = {IEEE International Joint Conference on Neural Networks}, title = {The {G}erman {T}raffic {S}ign {R}ecognition {B}enchmark: A multi-class classification competition}, year = {2011}, pages = {1453--1460} }

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import pandas as pd
import seaborn as sns
import pickle
import random
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq" -O train.p && rm -rf /tmp/cookies.txt
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1zJxB1YzBYuImaHBSxWGN-ZXPDRYN_CTX' -O valid.p
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1jZhZpEZkYFaaPPAwfd1cB8e-FK0aoeC0' -O test.p
# Out:
# --2020-09-29 07:31:28--  https://docs.google.com/uc?export=download&confirm=WmSA&id=1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq
# Resolving docs.google.com (docs.google.com)... 108.177.15.138, 108.177.15.101, 108.177.15.139, ...
# Connecting to docs.google.com (docs.google.com)|108.177.15.138|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-00-14-docs.googleusercontent.com/docs/securesc/gsa6unde88l6higl6oe8moone04cnved/dqkp800q7rjmkct7csj1bt6692d1hecl/1601364675000/17242455652310080862/06825591401903060220Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e=download [following]
# --2020-09-29 07:31:28--  https://doc-00-14-docs.googleusercontent.com/docs/securesc/gsa6unde88l6higl6oe8moone04cnved/dqkp800q7rjmkct7csj1bt6692d1hecl/1601364675000/17242455652310080862/06825591401903060220Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e=download
# Resolving doc-00-14-docs.googleusercontent.com (doc-00-14-docs.googleusercontent.com)... 74.125.133.132, 2a00:1450:400c:c07::84
# Connecting to doc-00-14-docs.googleusercontent.com (doc-00-14-docs.googleusercontent.com)|74.125.133.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=uomt8b08lpgto&continue=https://doc-00-14-docs.googleusercontent.com/docs/securesc/gsa6unde88l6higl6oe8moone04cnved/dqkp800q7rjmkct7csj1bt6692d1hecl/1601364675000/17242455652310080862/06825591401903060220Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e%3Ddownload&hash=2ashv76lqq442ckmjsnjmlm5fhbjeiqq [following]
# --2020-09-29 07:31:28--  https://docs.google.com/nonceSigner?nonce=uomt8b08lpgto&continue=https://doc-00-14-docs.googleusercontent.com/docs/securesc/gsa6unde88l6higl6oe8moone04cnved/dqkp800q7rjmkct7csj1bt6692d1hecl/1601364675000/17242455652310080862/06825591401903060220Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e%3Ddownload&hash=2ashv76lqq442ckmjsnjmlm5fhbjeiqq
# Connecting to docs.google.com (docs.google.com)|108.177.15.138|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-00-14-docs.googleusercontent.com/docs/securesc/gsa6unde88l6higl6oe8moone04cnved/dqkp800q7rjmkct7csj1bt6692d1hecl/1601364675000/17242455652310080862/06825591401903060220Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e=download&nonce=uomt8b08lpgto&user=06825591401903060220Z&hash=9754tvf25c9m4a8ji9q5dbn60l2pemo4 [following]
# --2020-09-29 07:31:29--  https://doc-00-14-docs.googleusercontent.com/docs/securesc/gsa6unde88l6higl6oe8moone04cnved/dqkp800q7rjmkct7csj1bt6692d1hecl/1601364675000/17242455652310080862/06825591401903060220Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e=download&nonce=uomt8b08lpgto&user=06825591401903060220Z&hash=9754tvf25c9m4a8ji9q5dbn60l2pemo4
# Connecting to doc-00-14-docs.googleusercontent.com (doc-00-14-docs.googleusercontent.com)|74.125.133.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/x-pascal]
# Saving to: ‘train.p’
#
# train.p                 [      <=>           ] 102.18M  86.3MB/s    in 1.2s
#
# 2020-09-29 07:31:30 (86.3 MB/s) - ‘train.p’ saved [107146452]
#
# --2020-09-29 07:31:30--  https://docs.google.com/uc?export=download&id=1zJxB1YzBYuImaHBSxWGN-ZXPDRYN_CTX
# Resolving docs.google.com (docs.google.com)... 142.250.13.138, 142.250.13.139, 142.250.13.100, ...
# Connecting to docs.google.com (docs.google.com)|142.250.13.138|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0c-7s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/udsiqtthabtcv64b713ngkrsachu7shl/1601364675000/17242455652310080862/*/1zJxB1YzBYuImaHBSxWGN-ZXPDRYN_CTX?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2020-09-29 07:31:31--  https://doc-0c-7s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/udsiqtthabtcv64b713ngkrsachu7shl/1601364675000/17242455652310080862/*/1zJxB1YzBYuImaHBSxWGN-ZXPDRYN_CTX?e=download
# Resolving doc-0c-7s-docs.googleusercontent.com (doc-0c-7s-docs.googleusercontent.com)... 74.125.133.132, 2a00:1450:400c:c07::84
# Connecting to doc-0c-7s-docs.googleusercontent.com (doc-0c-7s-docs.googleusercontent.com)|74.125.133.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/x-pascal]
# Saving to: ‘valid.p’
#
# valid.p                 [  <=>               ]  12.95M  31.4MB/s    in 0.4s
#
# 2020-09-29 07:31:32 (31.4 MB/s) - ‘valid.p’ saved [13578712]
#
# --2020-09-29 07:31:32--  https://docs.google.com/uc?export=download&id=1jZhZpEZkYFaaPPAwfd1cB8e-FK0aoeC0
# Resolving docs.google.com (docs.google.com)... 74.125.206.102, 74.125.206.139, 74.125.206.113, ...
# Connecting to docs.google.com (docs.google.com)|74.125.206.102|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0g-7s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/5r507oq5ht8aqeao582shkbqljr6k0kr/1601364675000/17242455652310080862/*/1jZhZpEZkYFaaPPAwfd1cB8e-FK0aoeC0?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2020-09-29 07:31:33--  https://doc-0g-7s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/5r507oq5ht8aqeao582shkbqljr6k0kr/1601364675000/17242455652310080862/*/1jZhZpEZkYFaaPPAwfd1cB8e-FK0aoeC0?e=download
# Resolving doc-0g-7s-docs.googleusercontent.com (doc-0g-7s-docs.googleusercontent.com)... 74.125.133.132, 2a00:1450:400c:c07::84
# Connecting to doc-0g-7s-docs.googleusercontent.com (doc-0g-7s-docs.googleusercontent.com)|74.125.133.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/x-pascal]
# Saving to: ‘test.p’
#
# test.p                  [   <=>              ]  37.09M  66.5MB/s    in 0.6s
#
# 2020-09-29 07:31:34 (66.5 MB/s) - ‘test.p’ saved [38888118]

# %%
with open("/content/train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("/content/valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("/content/test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']
X_validation, y_validation = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
X_train.shape
# Out:
# (34799, 32, 32, 3)

# %%
y_train.shape
# Out:
# (34799,)

# %%
X_validation.shape
# Out:
# (4410, 32, 32, 3)

# %%
y_validation.shape
# Out:
# (4410,)

# %%
X_test.shape
# Out:
# (12630, 32, 32, 3)

# %%
y_test.shape
# Out:
# (12630,)

# %% [markdown]
# # TASK #3: PERFROM IMAGES VISUALIZATION

# %%
i = np.random.randint(1, len(X_train))
plt.imshow(X_train[i])
y_train[i]
# Out:
# 38

# %%
# Let's view more images in a grid format
# Define the dimensions of the plot grid 
W_grid = 5
L_grid = 5

# fig, axes = plt.subplots(L_grid, W_grid)
# subplot return the figure object and axes object
# we can use the axes object to plot specific figures at various locations

fig, axes = plt.subplots(L_grid, W_grid, figsize = (10,10))

axes = axes.ravel() # flaten the 15 x 15 matrix into 225 array

n_training = len(X_train) # get the length of the training dataset

# Select a random number from 0 to n_training
for i in np.arange(0, W_grid * L_grid): # create evenly spaces variables 

    # Select a random number
    index = np.random.randint(0, n_training)
    # read and display an image with the selected index    
    axes[i].imshow( X_train[index])
    axes[i].set_title(y_train[index], fontsize = 15)
    axes[i].axis('off')

plt.subplots_adjust(hspace=0.4)

# %% [markdown]
# # TASK #4: CONVERT IMAGES TO GRAYSCALE AND PERFORM NORMALIZATION

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %% [markdown]
# #Since its an RGB image, so it means that you have add r with g with b and then divide it by 3 to get your desired grayscale image. Its done in this way. If you have an color image like the image shown above and you want to convert it into grayscale using average method.

# %%
X_train_gray = np.sum(X_train/3, axis = 3, keepdims = True)
X_test_gray = np.sum(X_test/3, axis = 3, keepdims = True)
X_validation_gray = np.sum(X_validation/3, axis = 3, keepdims = True)

# %%
X_train_gray.shape
# Out:
# (34799, 32, 32, 1)

# %%
X_test_gray.shape
# Out:
# (12630, 32, 32, 1)

# %%
X_validation_gray.shape
# Out:
# (4410, 32, 32, 1)

# %%
X_train_gray_norm = (X_train_gray - 128)/128
X_test_gray_norm = (X_test_gray - 128)/128
X_validation_gray_norm = (X_validation_gray - 128)/128

# %%
i = random.randint(1, len(X_train_gray))
plt.imshow(X_train_gray[i].squeeze(), cmap = 'gray')
plt.figure()
plt.imshow(X_train[i])
plt.figure()
plt.imshow(X_train_gray_norm[i].squeeze(), cmap = 'gray')

# %% [markdown]
# #Building the model

# %% [markdown]
# #Use this space for coding

# %%
from keras.utils import to_categorical
y_train = to_categorical(y_train, 43)
y_validation = to_categorical(y_validation, 43)
y_test = to_categorical(y_test, 43)

# %% [markdown]
# # Model 1

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout

model = Sequential()
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu', input_shape=X_train_gray_norm.shape[1:]))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(rate=0.5))
model.add(Dense(43, activation='softmax'))

#Compilation of the model
model.compile(
    loss='categorical_crossentropy', 
    optimizer='adam', 
    metrics=['accuracy']
)

# %%
history = model.fit(X_train_gray_norm, y_train, batch_size=32, epochs=50,validation_data=(X_validation_gray_norm, y_validation))
# Out:
# Epoch 1/50
# 1088/1088 [==============================] - 9s 9ms/step - loss: 0.9259 - accuracy: 0.7409 - val_loss: 0.1664 - val_accuracy: 0.9526
# Epoch 2/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.1775 - accuracy: 0.9466 - val_loss: 0.1423 - val_accuracy: 0.9576
# Epoch 3/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.1099 - accuracy: 0.9667 - val_loss: 0.0811 - val_accuracy: 0.9746
# Epoch 4/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0903 - accuracy: 0.9731 - val_loss: 0.0929 - val_accuracy: 0.9730
# Epoch 5/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0759 - accuracy: 0.9767 - val_loss: 0.0870 - val_accuracy: 0.9789
# Epoch 6/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0696 - accuracy: 0.9790 - val_loss: 0.0810 - val_accuracy: 0.9748
# Epoch 7/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0596 - accuracy: 0.9820 - val_loss: 0.0974 - val_accuracy: 0.9735
# Epoch 8/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0590 - accuracy: 0.9821 - val_loss: 0.1331 - val_accuracy: 0.9762
# Epoch 9/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0555 - accuracy: 0.9838 - val_loss: 0.0806 - val_accuracy: 0.9834
# Epoch 10/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0551 - accuracy: 0.9842 - val_loss: 0.1028 - val_accuracy: 0.9771
# Epoch 11/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0492 - accuracy: 0.9858 - val_loss: 0.0951 - val_accuracy: 0.9798
# Epoch 12/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0440 - accuracy: 0.9867 - val_loss: 0.1011 - val_accuracy: 0.9773
# Epoch 13/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0442 - accuracy: 0.9874 - val_loss: 0.0989 - val_accuracy: 0.9819
# Epoch 14/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0494 - accuracy: 0.9858 - val_loss: 0.1236 - val_accuracy: 0.9764
# Epoch 15/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0426 - accuracy: 0.9875 - val_loss: 0.1033 - val_accuracy: 0.9780
# Epoch 16/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0431 - accuracy: 0.9887 - val_loss: 0.1044 - val_accuracy: 0.9773
# Epoch 17/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0437 - accuracy: 0.9881 - val_loss: 0.0683 - val_accuracy: 0.9887
# Epoch 18/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0417 - accuracy: 0.9894 - val_loss: 0.0820 - val_accuracy: 0.9859
# Epoch 19/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0395 - accuracy: 0.9890 - val_loss: 0.1326 - val_accuracy: 0.9730
# Epoch 20/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0371 - accuracy: 0.9905 - val_loss: 0.1031 - val_accuracy: 0.9800
# Epoch 21/50
# 1088/1088 [==============================] - 10s 9ms/step - loss: 0.0388 - accuracy: 0.9896 - val_loss: 0.0949 - val_accuracy: 0.9866
# Epoch 22/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0519 - accuracy: 0.9875 - val_loss: 0.1042 - val_accuracy: 0.9794
# Epoch 23/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0297 - accuracy: 0.9915 - val_loss: 0.0787 - val_accuracy: 0.9898
# Epoch 24/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0392 - accuracy: 0.9907 - val_loss: 0.1426 - val_accuracy: 0.9705
# Epoch 25/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0360 - accuracy: 0.9905 - val_loss: 0.1365 - val_accuracy: 0.9762
# Epoch 26/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0316 - accuracy: 0.9914 - val_loss: 0.0730 - val_accuracy: 0.9875
# Epoch 27/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0365 - accuracy: 0.9908 - val_loss: 0.0815 - val_accuracy: 0.9880
# Epoch 28/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0304 - accuracy: 0.9922 - val_loss: 0.0629 - val_accuracy: 0.9871
# Epoch 29/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0367 - accuracy: 0.9909 - val_loss: 0.1917 - val_accuracy: 0.9800
# Epoch 30/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0396 - accuracy: 0.9900 - val_loss: 0.0696 - val_accuracy: 0.9887
# Epoch 31/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0355 - accuracy: 0.9916 - val_loss: 0.0886 - val_accuracy: 0.9868
# Epoch 32/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0352 - accuracy: 0.9913 - val_loss: 0.0777 - val_accuracy: 0.9864
# Epoch 33/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0299 - accuracy: 0.9926 - val_loss: 0.0663 - val_accuracy: 0.9882
# Epoch 34/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0326 - accuracy: 0.9920 - val_loss: 0.0936 - val_accuracy: 0.9834
# Epoch 35/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0363 - accuracy: 0.9914 - val_loss: 0.1481 - val_accuracy: 0.9680
# Epoch 36/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0277 - accuracy: 0.9923 - val_loss: 0.1480 - val_accuracy: 0.9834
# Epoch 37/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0349 - accuracy: 0.9917 - val_loss: 0.2012 - val_accuracy: 0.9800
# Epoch 38/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0427 - accuracy: 0.9908 - val_loss: 0.1088 - val_accuracy: 0.9875
# Epoch 39/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0308 - accuracy: 0.9927 - val_loss: 0.1100 - val_accuracy: 0.9866
# Epoch 40/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0369 - accuracy: 0.9920 - val_loss: 0.0754 - val_accuracy: 0.9866
# Epoch 41/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0381 - accuracy: 0.9915 - val_loss: 0.1366 - val_accuracy: 0.9855
# Epoch 42/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0330 - accuracy: 0.9928 - val_loss: 0.1197 - val_accuracy: 0.9830
# Epoch 43/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0326 - accuracy: 0.9930 - val_loss: 0.2190 - val_accuracy: 0.9810
# Epoch 44/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0363 - accuracy: 0.9926 - val_loss: 0.0967 - val_accuracy: 0.9875
# Epoch 45/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0342 - accuracy: 0.9928 - val_loss: 0.0751 - val_accuracy: 0.9884
# Epoch 46/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0408 - accuracy: 0.9922 - val_loss: 0.1018 - val_accuracy: 0.9839
# Epoch 47/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0423 - accuracy: 0.9915 - val_loss: 0.1034 - val_accuracy: 0.9837
# Epoch 48/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0346 - accuracy: 0.9931 - val_loss: 0.0930 - val_accuracy: 0.9855
# Epoch 49/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0331 - accuracy: 0.9931 - val_loss: 0.1414 - val_accuracy: 0.9825
# Epoch 50/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0382 - accuracy: 0.9926 - val_loss: 0.0848 - val_accuracy: 0.9875

# %% [markdown]
# ## **Model 2**

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

model1 = Sequential()

model1.add(Conv2D(32, kernel_size=(3,3), padding='same', activation='relu', input_shape=X_train_gray_norm.shape[1:]))
model1.add(Conv2D(32, kernel_size=(3,3), padding='same', activation='relu'))
model1.add(MaxPooling2D(pool_size=(2, 2)))
model1.add(Dropout(rate=0.2))

model1.add(Conv2D(64, kernel_size=(3, 3), padding='same', activation='relu'))
model1.add(Conv2D(64, kernel_size=(3, 3), padding='same', activation='relu'))
model1.add(MaxPooling2D(pool_size=(2, 2)))
model1.add(Dropout(rate=0.2))

model1.add(Flatten())
model1.add(Dense(256, activation='relu'))
model1.add(Dropout(rate=0.5))
model1.add(Dense(43, activation='softmax'))

model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               1048832
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 43)                11051
# =================================================================
# Total params: 1,124,875
# Trainable params: 1,124,875
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history1 = model1.fit(X_train_gray_norm, y_train, batch_size=100, epochs=50,validation_data=(X_validation_gray_norm, y_validation),verbose=1)
# Out:
# Epoch 1/50
# 348/348 [==============================] - 7s 19ms/step - loss: 1.6141 - accuracy: 0.5593 - val_loss: 0.3123 - val_accuracy: 0.9109
# Epoch 2/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.2619 - accuracy: 0.9194 - val_loss: 0.1279 - val_accuracy: 0.9626
# Epoch 3/50
# 348/348 [==============================] - 7s 19ms/step - loss: 0.1349 - accuracy: 0.9585 - val_loss: 0.0805 - val_accuracy: 0.9791
# Epoch 4/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0928 - accuracy: 0.9710 - val_loss: 0.0825 - val_accuracy: 0.9776
# Epoch 5/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0677 - accuracy: 0.9794 - val_loss: 0.0740 - val_accuracy: 0.9805
# Epoch 6/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0547 - accuracy: 0.9822 - val_loss: 0.0637 - val_accuracy: 0.9839
# Epoch 7/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0479 - accuracy: 0.9842 - val_loss: 0.0531 - val_accuracy: 0.9884
# Epoch 8/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0417 - accuracy: 0.9870 - val_loss: 0.0589 - val_accuracy: 0.9841
# Epoch 9/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0354 - accuracy: 0.9885 - val_loss: 0.0686 - val_accuracy: 0.9825
# Epoch 10/50
# 348/348 [==============================] - 7s 19ms/step - loss: 0.0369 - accuracy: 0.9880 - val_loss: 0.0544 - val_accuracy: 0.9878
# Epoch 11/50
# 348/348 [==============================] - 7s 20ms/step - loss: 0.0284 - accuracy: 0.9912 - val_loss: 0.0752 - val_accuracy: 0.9823
# Epoch 12/50
# 348/348 [==============================] - 7s 19ms/step - loss: 0.0289 - accuracy: 0.9908 - val_loss: 0.0606 - val_accuracy: 0.9832
# Epoch 13/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0273 - accuracy: 0.9912 - val_loss: 0.0548 - val_accuracy: 0.9834
# Epoch 14/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0216 - accuracy: 0.9928 - val_loss: 0.0608 - val_accuracy: 0.9805
# Epoch 15/50
# 348/348 [==============================] - 7s 19ms/step - loss: 0.0248 - accuracy: 0.9926 - val_loss: 0.0491 - val_accuracy: 0.9862
# Epoch 16/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0215 - accuracy: 0.9933 - val_loss: 0.0713 - val_accuracy: 0.9800
# Epoch 17/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0180 - accuracy: 0.9951 - val_loss: 0.0655 - val_accuracy: 0.9841
# Epoch 18/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0197 - accuracy: 0.9940 - val_loss: 0.0504 - val_accuracy: 0.9855
# Epoch 19/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0200 - accuracy: 0.9936 - val_loss: 0.0567 - val_accuracy: 0.9864
# Epoch 20/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0179 - accuracy: 0.9943 - val_loss: 0.0528 - val_accuracy: 0.9893
# Epoch 21/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0163 - accuracy: 0.9943 - val_loss: 0.0567 - val_accuracy: 0.9887
# Epoch 22/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0191 - accuracy: 0.9943 - val_loss: 0.0440 - val_accuracy: 0.9884
# Epoch 23/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0154 - accuracy: 0.9951 - val_loss: 0.0506 - val_accuracy: 0.9873
# Epoch 24/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0172 - accuracy: 0.9943 - val_loss: 0.0604 - val_accuracy: 0.9857
# Epoch 25/50
# 348/348 [==============================] - 7s 19ms/step - loss: 0.0162 - accuracy: 0.9948 - val_loss: 0.0566 - val_accuracy: 0.9832
# Epoch 26/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0160 - accuracy: 0.9951 - val_loss: 0.0707 - val_accuracy: 0.9880
# Epoch 27/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0136 - accuracy: 0.9962 - val_loss: 0.0567 - val_accuracy: 0.9896
# Epoch 28/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0140 - accuracy: 0.9958 - val_loss: 0.0794 - val_accuracy: 0.9828
# Epoch 29/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0127 - accuracy: 0.9958 - val_loss: 0.0393 - val_accuracy: 0.9887
# Epoch 30/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0161 - accuracy: 0.9953 - val_loss: 0.0893 - val_accuracy: 0.9821
# Epoch 31/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0155 - accuracy: 0.9955 - val_loss: 0.0788 - val_accuracy: 0.9823
# Epoch 32/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0114 - accuracy: 0.9966 - val_loss: 0.0574 - val_accuracy: 0.9868
# Epoch 33/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0140 - accuracy: 0.9958 - val_loss: 0.0695 - val_accuracy: 0.9857
# Epoch 34/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0149 - accuracy: 0.9953 - val_loss: 0.0615 - val_accuracy: 0.9866
# Epoch 35/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0116 - accuracy: 0.9964 - val_loss: 0.0678 - val_accuracy: 0.9850
# Epoch 36/50
# 348/348 [==============================] - 7s 19ms/step - loss: 0.0111 - accuracy: 0.9966 - val_loss: 0.0520 - val_accuracy: 0.9907
# Epoch 37/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0138 - accuracy: 0.9959 - val_loss: 0.0578 - val_accuracy: 0.9916
# Epoch 38/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0104 - accuracy: 0.9968 - val_loss: 0.0923 - val_accuracy: 0.9837
# Epoch 39/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0097 - accuracy: 0.9972 - val_loss: 0.0653 - val_accuracy: 0.9866
# Epoch 40/50
# 348/348 [==============================] - 7s 19ms/step - loss: 0.0110 - accuracy: 0.9967 - val_loss: 0.0730 - val_accuracy: 0.9864
# Epoch 41/50
# 348/348 [==============================] - 7s 19ms/step - loss: 0.0101 - accuracy: 0.9968 - val_loss: 0.0753 - val_accuracy: 0.9846
# Epoch 42/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0121 - accuracy: 0.9961 - val_loss: 0.0898 - val_accuracy: 0.9857
# Epoch 43/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0102 - accuracy: 0.9970 - val_loss: 0.0980 - val_accuracy: 0.9814
# Epoch 44/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0109 - accuracy: 0.9971 - val_loss: 0.1108 - val_accuracy: 0.9796
# Epoch 45/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0122 - accuracy: 0.9965 - val_loss: 0.1122 - val_accuracy: 0.9807
# Epoch 46/50
# 348/348 [==============================] - 7s 19ms/step - loss: 0.0102 - accuracy: 0.9970 - val_loss: 0.0739 - val_accuracy: 0.9884
# Epoch 47/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0117 - accuracy: 0.9964 - val_loss: 0.1237 - val_accuracy: 0.9771
# Epoch 48/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0107 - accuracy: 0.9967 - val_loss: 0.0714 - val_accuracy: 0.9880
# Epoch 49/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0105 - accuracy: 0.9971 - val_loss: 0.0749 - val_accuracy: 0.9839
# Epoch 50/50
# 348/348 [==============================] - 6s 19ms/step - loss: 0.0093 - accuracy: 0.9972 - val_loss: 0.0652 - val_accuracy: 0.9868

# %% [markdown]
# # Model 3

# %%
import keras
import tensorflow as tf

keras.backend.clear_session()

# %%
from keras.preprocessing.image import ImageDataGenerator
 
datagen = ImageDataGenerator(width_shift_range=0.1,
                            height_shift_range=0.1,
                            zoom_range=0.3,
                            shear_range=0.1,
                            rotation_range=9.)
 
datagen.fit(X_train)
batches = datagen.flow(X_train_gray_norm, y_train, batch_size = 32)
X_batch, y_batch = next(batches)
 
fig, axs = plt.subplots(1, 15, figsize=(20, 5))
fig.tight_layout()
 
for i in range(15):
    axs[i].imshow(X_batch[i].reshape(32, 32))
    axs[i].axis("off")
 
print(X_batch.shape)
# Out:
# (32, 32, 32, 1)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout,MaxPooling2D
from keras.optimizers import Adam


model2 = Sequential()
model2.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu', input_shape=X_train_gray_norm.shape[1:]))
model2.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model2.add(MaxPool2D(pool_size=(2, 2)))
model2.add(Dropout(rate=0.2))
model2.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model2.add(MaxPool2D(pool_size=(2, 2)))
model2.add(Dropout(rate=0.2))
model2.add(Flatten())
model2.add(Dense(256, activation='relu'))
model2.add(Dropout(rate=0.5))
model2.add(Dense(43, activation='softmax'))

model2.compile(
    loss='categorical_crossentropy', 
    optimizer='adam', 
    metrics=['accuracy'])

# %%
model2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 32)        832
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 26, 26, 64)        18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 11, 11, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1600)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               409856
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 43)                11051
# =================================================================
# Total params: 477,163
# Trainable params: 477,163
# Non-trainable params: 0
# _________________________________________________________________

# %%
history2 = model2.fit_generator(datagen.flow(X_train_gray_norm, y_train, batch_size=32),epochs=50,validation_data=(X_validation_gray_norm,y_validation))
# Out:
# WARNING:tensorflow:From <ipython-input-75-ccbdd3d93531>:1: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
# 1088/1088 [==============================] - 21s 19ms/step - loss: 1.9047 - accuracy: 0.4650 - val_loss: 0.3841 - val_accuracy: 0.8689
# Epoch 2/50
# 1088/1088 [==============================] - 20s 19ms/step - loss: 0.6864 - accuracy: 0.7910 - val_loss: 0.1321 - val_accuracy: 0.9610
# Epoch 3/50
# 1088/1088 [==============================] - 20s 18ms/step - loss: 0.4427 - accuracy: 0.8670 - val_loss: 0.1149 - val_accuracy: 0.9644
# Epoch 4/50
# 1088/1088 [==============================] - 20s 18ms/step - loss: 0.3357 - accuracy: 0.8973 - val_loss: 0.0709 - val_accuracy: 0.9785
# Epoch 5/50
# 1088/1088 [==============================] - 20s 18ms/step - loss: 0.2841 - accuracy: 0.9138 - val_loss: 0.0568 - val_accuracy: 0.9821
# Epoch 6/50
# 1088/1088 [==============================] - 20s 18ms/step - loss: 0.2508 - accuracy: 0.9246 - val_loss: 0.0431 - val_accuracy: 0.9846
# Epoch 7/50
# 1088/1088 [==============================] - 20s 18ms/step - loss: 0.2231 - accuracy: 0.9313 - val_loss: 0.0377 - val_accuracy: 0.9891
# Epoch 8/50
# 1088/1088 [==============================] - 19s 18ms/step - loss: 0.2010 - accuracy: 0.9388 - val_loss: 0.0393 - val_accuracy: 0.9893
# Epoch 9/50
# 1088/1088 [==============================] - 19s 18ms/step - loss: 0.1938 - accuracy: 0.9423 - val_loss: 0.0443 - val_accuracy: 0.9855
# Epoch 10/50
# 1088/1088 [==============================] - 20s 18ms/step - loss: 0.1731 - accuracy: 0.9468 - val_loss: 0.0374 - val_accuracy: 0.9898
# Epoch 11/50
# 1088/1088 [==============================] - 19s 18ms/step - loss: 0.1700 - accuracy: 0.9474 - val_loss: 0.0223 - val_accuracy: 0.9941
# Epoch 12/50
# 1088/1088 [==============================] - 19s 18ms/step - loss: 0.1697 - accuracy: 0.9492 - val_loss: 0.0422 - val_accuracy: 0.9884
# Epoch 13/50
# 1088/1088 [==============================] - 19s 18ms/step - loss: 0.1582 - accuracy: 0.9531 - val_loss: 0.0390 - val_accuracy: 0.9889
# Epoch 14/50
# 1088/1088 [==============================] - 19s 18ms/step - loss: 0.1526 - accuracy: 0.9530 - val_loss: 0.0280 - val_accuracy: 0.9914
# Epoch 15/50
# 1088/1088 [==============================] - 19s 17ms/step - loss: 0.1501 - accuracy: 0.9539 - val_loss: 0.0325 - val_accuracy: 0.9898
# Epoch 16/50
# 1088/1088 [==============================] - 19s 18ms/step - loss: 0.1368 - accuracy: 0.9596 - val_loss: 0.0290 - val_accuracy: 0.9912
# Epoch 17/50
# 1088/1088 [==============================] - 20s 18ms/step - loss: 0.1411 - accuracy: 0.9585 - val_loss: 0.0443 - val_accuracy: 0.9873
# Epoch 18/50
# 1088/1088 [==============================] - 19s 18ms/step - loss: 0.1374 - accuracy: 0.9603 - val_loss: 0.0309 - val_accuracy: 0.9912
# Epoch 19/50
# 1088/1088 [==============================] - 19s 18ms/step - loss: 0.1329 - accuracy: 0.9604 - val_loss: 0.0266 - val_accuracy: 0.9918
# Epoch 20/50
# 1088/1088 [==============================] - 19s 18ms/step - loss: 0.1243 - accuracy: 0.9627 - val_loss: 0.0236 - val_accuracy: 0.9932
# Epoch 21/50
# 1088/1088 [==============================] - 19s 17ms/step - loss: 0.1352 - accuracy: 0.9597 - val_loss: 0.0228 - val_accuracy: 0.9934
# Epoch 22/50
# 1088/1088 [==============================] - 19s 18ms/step - loss: 0.1236 - accuracy: 0.9632 - val_loss: 0.0283 - val_accuracy: 0.9941
# Epoch 23/50
# 1088/1088 [==============================] - 19s 18ms/step - loss: 0.1203 - accuracy: 0.9644 - val_loss: 0.0383 - val_accuracy: 0.9889
# Epoch 24/50
# 1088/1088 [==============================] - 19s 18ms/step - loss: 0.1179 - accuracy: 0.9657 - val_loss: 0.0379 - val_accuracy: 0.9880
# Epoch 25/50
# 1088/1088 [==============================] - 19s 17ms/step - loss: 0.1232 - accuracy: 0.9638 - val_loss: 0.0277 - val_accuracy: 0.9930
# Epoch 26/50
# 1088/1088 [==============================] - 19s 18ms/step - loss: 0.1171 - accuracy: 0.9660 - val_loss: 0.0261 - val_accuracy: 0.9934
# Epoch 27/50
# 1088/1088 [==============================] - 19s 17ms/step - loss: 0.1237 - accuracy: 0.9645 - val_loss: 0.0196 - val_accuracy: 0.9941
# Epoch 28/50
# 1088/1088 [==============================] - 19s 17ms/step - loss: 0.1124 - accuracy: 0.9670 - val_loss: 0.0273 - val_accuracy: 0.9921
# Epoch 29/50
# 1088/1088 [==============================] - 19s 17ms/step - loss: 0.1088 - accuracy: 0.9686 - val_loss: 0.0247 - val_accuracy: 0.9925
# Epoch 30/50
# 1088/1088 [==============================] - 19s 17ms/step - loss: 0.1044 - accuracy: 0.9701 - val_loss: 0.0247 - val_accuracy: 0.9943
# Epoch 31/50
# 1088/1088 [==============================] - 19s 17ms/step - loss: 0.1051 - accuracy: 0.9701 - val_loss: 0.0215 - val_accuracy: 0.9946
# Epoch 32/50
# 1088/1088 [==============================] - 19s 17ms/step - loss: 0.1049 - accuracy: 0.9686 - val_loss: 0.0367 - val_accuracy: 0.9902
# Epoch 33/50
# 1088/1088 [==============================] - 20s 18ms/step - loss: 0.1141 - accuracy: 0.9678 - val_loss: 0.0441 - val_accuracy: 0.9868
# Epoch 34/50
# 1088/1088 [==============================] - 19s 18ms/step - loss: 0.1026 - accuracy: 0.9700 - val_loss: 0.0295 - val_accuracy: 0.9905
# Epoch 35/50
# 1088/1088 [==============================] - 19s 17ms/step - loss: 0.1053 - accuracy: 0.9703 - val_loss: 0.0204 - val_accuracy: 0.9937
# Epoch 36/50
# 1088/1088 [==============================] - 19s 17ms/step - loss: 0.1086 - accuracy: 0.9697 - val_loss: 0.0350 - val_accuracy: 0.9905
# Epoch 37/50
# 1088/1088 [==============================] - 19s 18ms/step - loss: 0.1030 - accuracy: 0.9716 - val_loss: 0.0175 - val_accuracy: 0.9948
# Epoch 38/50
# 1088/1088 [==============================] - 19s 18ms/step - loss: 0.0971 - accuracy: 0.9720 - val_loss: 0.0297 - val_accuracy: 0.9916
# Epoch 39/50
# 1088/1088 [==============================] - 19s 17ms/step - loss: 0.1060 - accuracy: 0.9714 - val_loss: 0.0366 - val_accuracy: 0.9887
# Epoch 40/50
# 1088/1088 [==============================] - 19s 17ms/step - loss: 0.0989 - accuracy: 0.9729 - val_loss: 0.0285 - val_accuracy: 0.9941
# Epoch 41/50
# 1088/1088 [==============================] - 19s 17ms/step - loss: 0.0978 - accuracy: 0.9731 - val_loss: 0.0248 - val_accuracy: 0.9925
# Epoch 42/50
# 1088/1088 [==============================] - 19s 17ms/step - loss: 0.1027 - accuracy: 0.9711 - val_loss: 0.0230 - val_accuracy: 0.9932
# Epoch 43/50
# 1088/1088 [==============================] - 19s 17ms/step - loss: 0.0991 - accuracy: 0.9721 - val_loss: 0.0312 - val_accuracy: 0.9914
# Epoch 44/50
# 1088/1088 [==============================] - 19s 17ms/step - loss: 0.0962 - accuracy: 0.9730 - val_loss: 0.0393 - val_accuracy: 0.9884
# Epoch 45/50
# 1088/1088 [==============================] - 19s 17ms/step - loss: 0.0899 - accuracy: 0.9746 - val_loss: 0.0319 - val_accuracy: 0.9907
# Epoch 46/50
# 1088/1088 [==============================] - 19s 17ms/step - loss: 0.1007 - accuracy: 0.9721 - val_loss: 0.0437 - val_accuracy: 0.9866
# Epoch 47/50
# 1088/1088 [==============================] - 19s 17ms/step - loss: 0.0997 - accuracy: 0.9722 - val_loss: 0.0461 - val_accuracy: 0.9889
# Epoch 48/50
# 1088/1088 [==============================] - 19s 17ms/step - loss: 0.1012 - accuracy: 0.9726 - val_loss: 0.0355 - val_accuracy: 0.9907
# Epoch 49/50
# 1088/1088 [==============================] - 19s 18ms/step - loss: 0.0903 - accuracy: 0.9748 - val_loss: 0.0218 - val_accuracy: 0.9943
# Epoch 50/50
# 1088/1088 [==============================] - 19s 18ms/step - loss: 0.0961 - accuracy: 0.9745 - val_loss: 0.0228 - val_accuracy: 0.9927

# %% [markdown]
# # TASK #8: ASSESS TRAINED CNN MODEL PERFORMANCE

# %% [markdown]
# #Marks will be given on basis of next code cells results

# %%
score = model.evaluate(X_test_gray_norm, y_test)
print('Test Accuracy: {}'.format(score[1]))
# Out:
# 395/395 [==============================] - 2s 5ms/step - loss: 0.2303 - accuracy: 0.9720
# Test Accuracy: 0.9719715118408203

# %%
score1 = model1.evaluate(X_test_gray_norm, y_test)
print('Test Accuracy: {}'.format(score1[1]))
# Out:
# 395/395 [==============================] - 2s 4ms/step - loss: 0.1893 - accuracy: 0.9785
# Test Accuracy: 0.9785431623458862

# %%
score2 = model2.evaluate(X_test_gray_norm, y_test)
print('Test Accuracy: {}'.format(score2[1]))
# Out:
# 395/395 [==============================] - 2s 5ms/step - loss: 0.0983 - accuracy: 0.9808
# Test Accuracy: 0.9808392524719238

# %% [markdown]
# #Attach a screen shot of your results as proof below this cell

# %% [markdown]
# ![Screenshot 2020-09-29 at 3.15.51 PM.png](data:image/png;base64,...)

# %% [markdown]
# #Other helper functions

# %%
history2.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
accuracy = history2.history['accuracy']
val_accuracy = history2.history['val_accuracy']
loss = history2.history['loss']
val_loss = history2.history['val_loss']

# %%
epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'bo', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# %%
plt.plot(epochs, loss, 'ro', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()
