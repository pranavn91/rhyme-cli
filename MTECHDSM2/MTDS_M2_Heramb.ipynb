# %% [markdown]
# # TASK #2: MOUNT DRIVE AND IMPORT LIBRARIES/DATASETS

# %% [markdown]
# - In this case study, we want to classify images of traffic signs using deep Convolutional Neural Networks (CNNs).
# - The dataset consists of 43 different classes of images.
# - Classes are as listed below:
#   - 0 = Speed limit (20km/h)
#   - 1 = Speed limit (30km/h)
#   - 2 = Speed limit (50km/h)
#   - 3 = Speed limit (60km/h)
#   - 4 = Speed limit (70km/h)
#   - 5 = Speed limit (80km/h)
#   - 6 = End of speed limit (80km/h)
#   - 7 = Speed limit (100km/h)
#   - 8 = Speed limit (120km/h)
#   - 9 = No passing
#   - 10 = No passing for vehicles over 3.5 metric tons
#   - 11 = Right-of-way at the next intersection
#   - 12 = Priority road
#   - 13 = Yield
#   - 14 = Stop
#   - 15 = No vehicles
#   - 16 = Vehicles over 3.5 metric tons prohibited
#   - 17 = No entry
#   - 18 = General caution
#   - 19 = Dangerous curve to the left
#   - 20 = Dangerous curve to the right
#   - 21 = Double curve
#   - 22 = Bumpy road
#   - 23 = Slippery road
#   - 24 = Road narrows on the right
#   - 25 = Road work
#   - 26 = Traffic signals
#   - 27 = Pedestrians
#   - 28 = Children crossing
#   - 29 = Bicycles crossing
#   - 30 = Beware of ice/snow
#   - 31 = Wild animals crossing
#   - 32 = End of all speed and passing limits
#   - 33 = Turn right ahead
#   - 34 = Turn left ahead
#   - 35 = Ahead only
#   - 36 = Go straight or right
#   - 37 = Go straight or left
#   - 38 = Keep right
#   - 39 = Keep left
#   - 40 = Roundabout mandatory
#   - 41 = End of no passing
#   - 42 = End of no passing by vehicles over 3.5 metric tons
#
# - Citation
# J. Stallkamp, M. Schlipsing, J. Salmen, and C. Igel. The German Traffic Sign Recognition Benchmark: A multi-class classification competition. In Proceedings of the IEEE International Joint Conference on Neural Networks, pages 1453–1460. 2011.
# @inproceedings{Stallkamp-IJCNN-2011, author = {Johannes Stallkamp and Marc Schlipsing and Jan Salmen and Christian Igel}, booktitle = {IEEE International Joint Conference on Neural Networks}, title = {The {G}erman {T}raffic {S}ign {R}ecognition {B}enchmark: A multi-class classification competition}, year = {2011}, pages = {1453--1460} }

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import pandas as pd
import seaborn as sns
import pickle
import random
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq" -O train.p && rm -rf /tmp/cookies.txt
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1zJxB1YzBYuImaHBSxWGN-ZXPDRYN_CTX' -O valid.p
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1jZhZpEZkYFaaPPAwfd1cB8e-FK0aoeC0' -O test.p
# Out:
# --2020-09-29 10:08:45--  https://docs.google.com/uc?export=download&confirm=IDT5&id=1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq
# Resolving docs.google.com (docs.google.com)... 108.177.127.139, 108.177.127.138, 108.177.127.102, ...
# Connecting to docs.google.com (docs.google.com)|108.177.127.139|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-14-5g-docs.googleusercontent.com/docs/securesc/0lddarntt1bof3ohvgd4evcpjmkjpuho/ku3eac341tkgk63k0vkfd644tul404q7/1601374125000/17242455652310080862/13365797518916448573Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e=download [following]
# --2020-09-29 10:08:45--  https://doc-14-5g-docs.googleusercontent.com/docs/securesc/0lddarntt1bof3ohvgd4evcpjmkjpuho/ku3eac341tkgk63k0vkfd644tul404q7/1601374125000/17242455652310080862/13365797518916448573Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e=download
# Resolving doc-14-5g-docs.googleusercontent.com (doc-14-5g-docs.googleusercontent.com)... 108.177.127.132, 2a00:1450:4013:c07::84
# Connecting to doc-14-5g-docs.googleusercontent.com (doc-14-5g-docs.googleusercontent.com)|108.177.127.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=tki7qdlugr3pi&continue=https://doc-14-5g-docs.googleusercontent.com/docs/securesc/0lddarntt1bof3ohvgd4evcpjmkjpuho/ku3eac341tkgk63k0vkfd644tul404q7/1601374125000/17242455652310080862/13365797518916448573Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e%3Ddownload&hash=j05ht2i88k0ooegootjt3997bl9n04er [following]
# --2020-09-29 10:08:45--  https://docs.google.com/nonceSigner?nonce=tki7qdlugr3pi&continue=https://doc-14-5g-docs.googleusercontent.com/docs/securesc/0lddarntt1bof3ohvgd4evcpjmkjpuho/ku3eac341tkgk63k0vkfd644tul404q7/1601374125000/17242455652310080862/13365797518916448573Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e%3Ddownload&hash=j05ht2i88k0ooegootjt3997bl9n04er
# Connecting to docs.google.com (docs.google.com)|108.177.127.139|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-14-5g-docs.googleusercontent.com/docs/securesc/0lddarntt1bof3ohvgd4evcpjmkjpuho/ku3eac341tkgk63k0vkfd644tul404q7/1601374125000/17242455652310080862/13365797518916448573Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e=download&nonce=tki7qdlugr3pi&user=13365797518916448573Z&hash=9m37pvklnjvctsh50o842pmpifon32us [following]
# --2020-09-29 10:08:46--  https://doc-14-5g-docs.googleusercontent.com/docs/securesc/0lddarntt1bof3ohvgd4evcpjmkjpuho/ku3eac341tkgk63k0vkfd644tul404q7/1601374125000/17242455652310080862/13365797518916448573Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e=download&nonce=tki7qdlugr3pi&user=13365797518916448573Z&hash=9m37pvklnjvctsh50o842pmpifon32us
# Connecting to doc-14-5g-docs.googleusercontent.com (doc-14-5g-docs.googleusercontent.com)|108.177.127.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/x-pascal]
# Saving to: ‘train.p’
#
# train.p                 [    <=>             ] 102.18M   161MB/s    in 0.6s
#
# 2020-09-29 10:08:46 (161 MB/s) - ‘train.p’ saved [107146452]
#
# --2020-09-29 10:08:46--  https://docs.google.com/uc?export=download&id=1zJxB1YzBYuImaHBSxWGN-ZXPDRYN_CTX
# Resolving docs.google.com (docs.google.com)... 108.177.127.101, 108.177.127.138, 108.177.127.102, ...
# Connecting to docs.google.com (docs.google.com)|108.177.127.101|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0c-7s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/gjtf0to90tmnkee6g6qqv9jcfo1ds4h3/1601374125000/17242455652310080862/*/1zJxB1YzBYuImaHBSxWGN-ZXPDRYN_CTX?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2020-09-29 10:08:48--  https://doc-0c-7s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/gjtf0to90tmnkee6g6qqv9jcfo1ds4h3/1601374125000/17242455652310080862/*/1zJxB1YzBYuImaHBSxWGN-ZXPDRYN_CTX?e=download
# Resolving doc-0c-7s-docs.googleusercontent.com (doc-0c-7s-docs.googleusercontent.com)... 108.177.127.132, 2a00:1450:4013:c07::84
# Connecting to doc-0c-7s-docs.googleusercontent.com (doc-0c-7s-docs.googleusercontent.com)|108.177.127.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/x-pascal]
# Saving to: ‘valid.p’
#
# valid.p                 [  <=>               ]  12.95M  39.5MB/s    in 0.3s
#
# 2020-09-29 10:08:49 (39.5 MB/s) - ‘valid.p’ saved [13578712]
#
# --2020-09-29 10:08:49--  https://docs.google.com/uc?export=download&id=1jZhZpEZkYFaaPPAwfd1cB8e-FK0aoeC0
# Resolving docs.google.com (docs.google.com)... 108.177.119.102, 108.177.119.100, 108.177.119.139, ...
# Connecting to docs.google.com (docs.google.com)|108.177.119.102|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0g-7s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/qqe8pir71jih7ljrljsilda0g2jmf23j/1601374125000/17242455652310080862/*/1jZhZpEZkYFaaPPAwfd1cB8e-FK0aoeC0?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2020-09-29 10:08:50--  https://doc-0g-7s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/qqe8pir71jih7ljrljsilda0g2jmf23j/1601374125000/17242455652310080862/*/1jZhZpEZkYFaaPPAwfd1cB8e-FK0aoeC0?e=download
# Resolving doc-0g-7s-docs.googleusercontent.com (doc-0g-7s-docs.googleusercontent.com)... 108.177.127.132, 2a00:1450:4013:c07::84
# Connecting to doc-0g-7s-docs.googleusercontent.com (doc-0g-7s-docs.googleusercontent.com)|108.177.127.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/x-pascal]
# Saving to: ‘test.p’
#
# test.p                  [  <=>               ]  37.09M   116MB/s    in 0.3s
#
# 2020-09-29 10:08:50 (116 MB/s) - ‘test.p’ saved [38888118]

# %%
with open("/content/train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("/content/valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("/content/test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']
X_validation, y_validation = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
X_train.shape
# Out:
# (34799, 32, 32, 3)

# %%
y_train.shape
# Out:
# (34799,)

# %%
X_validation.shape
# Out:
# (4410, 32, 32, 3)

# %%
y_validation.shape
# Out:
# (4410,)

# %%
y_test.shape
# Out:
# (12630,)

# %% [markdown]
# # TASK #3: PERFROM IMAGES VISUALIZATION

# %%
i = np.random.randint(1, len(X_train))
plt.imshow(X_train[i])
y_train[i]
# Out:
# 35

# %%
# Let's view more images in a grid format
# Define the dimensions of the plot grid 
W_grid = 5
L_grid = 5

# fig, axes = plt.subplots(L_grid, W_grid)
# subplot return the figure object and axes object
# we can use the axes object to plot specific figures at various locations

fig, axes = plt.subplots(L_grid, W_grid, figsize = (10,10))

axes = axes.ravel() # flaten the 15 x 15 matrix into 225 array

n_training = len(X_train) # get the length of the training dataset

# Select a random number from 0 to n_training
for i in np.arange(0, W_grid * L_grid): # create evenly spaces variables 

    # Select a random number
    index = np.random.randint(0, n_training)
    # read and display an image with the selected index    
    axes[i].imshow( X_train[index])
    axes[i].set_title(y_train[index], fontsize = 15)
    axes[i].axis('off')

plt.subplots_adjust(hspace=0.4)

# %% [markdown]
# # TASK #4: CONVERT IMAGES TO GRAYSCALE AND PERFORM NORMALIZATION

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %% [markdown]
# #Since its an RGB image, so it means that you have add r with g with b and then divide it by 3 to get your desired grayscale image. Its done in this way. If you have an color image like the image shown above and you want to convert it into grayscale using average method.

# %%
X_train_gray = np.sum(X_train/3, axis = 3, keepdims = True)
X_test_gray = np.sum(X_test/3, axis = 3, keepdims = True)
X_validation_gray = np.sum(X_validation/3, axis = 3, keepdims = True)

# %%
X_train_gray.shape
# Out:
# (34799, 32, 32, 1)

# %%
X_test_gray.shape
# Out:
# (12630, 32, 32, 1)

# %%
X_validation_gray.shape
# Out:
# (4410, 32, 32, 1)

# %%
X_train_gray_norm = (X_train_gray - 128)/128
X_test_gray_norm = (X_test_gray - 128)/128
X_validation_gray_norm = (X_validation_gray - 128)/128

# %%
i = random.randint(1, len(X_train_gray))
plt.imshow(X_train_gray[i].squeeze(), cmap = 'gray')
plt.figure()
plt.imshow(X_train[i])
plt.figure()
plt.imshow(X_train_gray_norm[i].squeeze(), cmap = 'gray')

# %% [markdown]
# #Building the model

# %% [markdown]
# #Use this space for coding

# %% [markdown]
# Now I updated whole new dataset for Training, Test and Validation

# %%
print("Training Dataset Shape :",X_train_gray_norm.shape, y_train.shape)
print("Test Dataset Shape :",X_test_gray_norm.shape, y_test.shape)
print("Validation Dataset Shape :",X_validation_gray_norm.shape, y_validation.shape)
# Out:
# Training Dataset Shape : (34799, 32, 32, 1) (34799,)
# Test Dataset Shape : (12630, 32, 32, 1) (12630,)
# Validation Dataset Shape : (4410, 32, 32, 1) (4410,)

# %%
from keras.utils import to_categorical
y_train = to_categorical(y_train, 43)
y_validation = to_categorical(y_validation, 43)
y_test = to_categorical(y_test, 43)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout

heramb = Sequential()

heramb.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu', 
                  input_shape=X_train_gray_norm.shape[1:]))
heramb.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
heramb.add(MaxPool2D(pool_size=(2, 2)))
heramb.add(Dropout(rate=0.25))
heramb.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
heramb.add(MaxPool2D(pool_size=(2, 2)))
heramb.add(Dropout(rate=0.25))
heramb.add(Flatten())
heramb.add(Dense(256, activation='relu'))
heramb.add(Dropout(rate=0.5))
heramb.add(Dense(43, activation='softmax'))

#Compiling the Heramb model
heramb.compile(
    loss='categorical_crossentropy', 
    optimizer='adam', 
    metrics=['accuracy']
)

# %%
#using 50 epochs for the training and saving the accuracy for each epoch
epochs = 50
history = heramb.fit(X_train_gray_norm, y_train, batch_size=32, epochs=epochs,
validation_data=(X_validation_gray_norm, y_validation))
# Out:
# Epoch 1/50
# 1088/1088 [==============================] - 5s 4ms/step - loss: 0.9373 - accuracy: 0.7390 - val_loss: 0.1504 - val_accuracy: 0.9537
# Epoch 2/50
# 1088/1088 [==============================] - 5s 4ms/step - loss: 0.1765 - accuracy: 0.9476 - val_loss: 0.0971 - val_accuracy: 0.9705
# Epoch 3/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.1158 - accuracy: 0.9654 - val_loss: 0.0744 - val_accuracy: 0.9789
# Epoch 4/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.0887 - accuracy: 0.9737 - val_loss: 0.0841 - val_accuracy: 0.9782
# Epoch 5/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.0791 - accuracy: 0.9769 - val_loss: 0.0843 - val_accuracy: 0.9776
# Epoch 6/50
# 1088/1088 [==============================] - 5s 4ms/step - loss: 0.0669 - accuracy: 0.9788 - val_loss: 0.0889 - val_accuracy: 0.9787
# Epoch 7/50
# 1088/1088 [==============================] - 5s 4ms/step - loss: 0.0608 - accuracy: 0.9810 - val_loss: 0.0944 - val_accuracy: 0.9805
# Epoch 8/50
# 1088/1088 [==============================] - 5s 4ms/step - loss: 0.0561 - accuracy: 0.9830 - val_loss: 0.0712 - val_accuracy: 0.9837
# Epoch 9/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.0530 - accuracy: 0.9842 - val_loss: 0.0733 - val_accuracy: 0.9823
# Epoch 10/50
# 1088/1088 [==============================] - 5s 4ms/step - loss: 0.0566 - accuracy: 0.9833 - val_loss: 0.0751 - val_accuracy: 0.9814
# Epoch 11/50
# 1088/1088 [==============================] - 5s 4ms/step - loss: 0.0455 - accuracy: 0.9865 - val_loss: 0.1765 - val_accuracy: 0.9590
# Epoch 12/50
# 1088/1088 [==============================] - 5s 4ms/step - loss: 0.0494 - accuracy: 0.9853 - val_loss: 0.0733 - val_accuracy: 0.9810
# Epoch 13/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.0468 - accuracy: 0.9861 - val_loss: 0.0930 - val_accuracy: 0.9778
# Epoch 14/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.0516 - accuracy: 0.9859 - val_loss: 0.0717 - val_accuracy: 0.9823
# Epoch 15/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.0408 - accuracy: 0.9876 - val_loss: 0.0797 - val_accuracy: 0.9816
# Epoch 16/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.0387 - accuracy: 0.9891 - val_loss: 0.0541 - val_accuracy: 0.9898
# Epoch 17/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.0409 - accuracy: 0.9884 - val_loss: 0.0797 - val_accuracy: 0.9798
# Epoch 18/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.0384 - accuracy: 0.9893 - val_loss: 0.1515 - val_accuracy: 0.9685
# Epoch 19/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.0432 - accuracy: 0.9882 - val_loss: 0.1269 - val_accuracy: 0.9776
# Epoch 20/50
# 1088/1088 [==============================] - 5s 4ms/step - loss: 0.0418 - accuracy: 0.9883 - val_loss: 0.0903 - val_accuracy: 0.9796
# Epoch 21/50
# 1088/1088 [==============================] - 5s 4ms/step - loss: 0.0412 - accuracy: 0.9886 - val_loss: 0.1559 - val_accuracy: 0.9635
# Epoch 22/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.0375 - accuracy: 0.9899 - val_loss: 0.0688 - val_accuracy: 0.9887
# Epoch 23/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.0389 - accuracy: 0.9897 - val_loss: 0.1008 - val_accuracy: 0.9721
# Epoch 24/50
# 1088/1088 [==============================] - 5s 4ms/step - loss: 0.0379 - accuracy: 0.9899 - val_loss: 0.1028 - val_accuracy: 0.9834
# Epoch 25/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.0369 - accuracy: 0.9897 - val_loss: 0.1361 - val_accuracy: 0.9739
# Epoch 26/50
# 1088/1088 [==============================] - 5s 4ms/step - loss: 0.0357 - accuracy: 0.9900 - val_loss: 0.2115 - val_accuracy: 0.9798
# Epoch 27/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.0398 - accuracy: 0.9899 - val_loss: 0.1116 - val_accuracy: 0.9787
# Epoch 28/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.0341 - accuracy: 0.9912 - val_loss: 0.1033 - val_accuracy: 0.9844
# Epoch 29/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.0381 - accuracy: 0.9904 - val_loss: 0.1024 - val_accuracy: 0.9832
# Epoch 30/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.0371 - accuracy: 0.9905 - val_loss: 0.1136 - val_accuracy: 0.9816
# Epoch 31/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.0320 - accuracy: 0.9921 - val_loss: 0.0828 - val_accuracy: 0.9887
# Epoch 32/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.0292 - accuracy: 0.9922 - val_loss: 0.0885 - val_accuracy: 0.9837
# Epoch 33/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.0298 - accuracy: 0.9916 - val_loss: 0.1110 - val_accuracy: 0.9850
# Epoch 34/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.0395 - accuracy: 0.9911 - val_loss: 0.0879 - val_accuracy: 0.9875
# Epoch 35/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.0318 - accuracy: 0.9917 - val_loss: 0.0947 - val_accuracy: 0.9855
# Epoch 36/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.0378 - accuracy: 0.9914 - val_loss: 0.1521 - val_accuracy: 0.9757
# Epoch 37/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.0418 - accuracy: 0.9900 - val_loss: 0.1296 - val_accuracy: 0.9825
# Epoch 38/50
# 1088/1088 [==============================] - 5s 4ms/step - loss: 0.0298 - accuracy: 0.9928 - val_loss: 0.1569 - val_accuracy: 0.9791
# Epoch 39/50
# 1088/1088 [==============================] - 5s 4ms/step - loss: 0.0352 - accuracy: 0.9920 - val_loss: 0.1147 - val_accuracy: 0.9828
# Epoch 40/50
# 1088/1088 [==============================] - 5s 4ms/step - loss: 0.0325 - accuracy: 0.9918 - val_loss: 0.1145 - val_accuracy: 0.9866
# Epoch 41/50
# 1088/1088 [==============================] - 5s 4ms/step - loss: 0.0332 - accuracy: 0.9922 - val_loss: 0.1367 - val_accuracy: 0.9834
# Epoch 42/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.0315 - accuracy: 0.9933 - val_loss: 0.1142 - val_accuracy: 0.9807
# Epoch 43/50
# 1088/1088 [==============================] - 5s 4ms/step - loss: 0.0386 - accuracy: 0.9918 - val_loss: 0.1161 - val_accuracy: 0.9834
# Epoch 44/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.0360 - accuracy: 0.9920 - val_loss: 0.1027 - val_accuracy: 0.9875
# Epoch 45/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.0310 - accuracy: 0.9926 - val_loss: 0.1062 - val_accuracy: 0.9868
# Epoch 46/50
# 1088/1088 [==============================] - 4s 4ms/step - loss: 0.0321 - accuracy: 0.9924 - val_loss: 0.0985 - val_accuracy: 0.9882
# Epoch 47/50
# 1088/1088 [==============================] - 5s 4ms/step - loss: 0.0333 - accuracy: 0.9933 - val_loss: 0.0830 - val_accuracy: 0.9900
# Epoch 48/50
# 1088/1088 [==============================] - 5s 4ms/step - loss: 0.0348 - accuracy: 0.9923 - val_loss: 0.0720 - val_accuracy: 0.9912
# Epoch 49/50
# 1088/1088 [==============================] - 5s 4ms/step - loss: 0.0316 - accuracy: 0.9926 - val_loss: 0.1743 - val_accuracy: 0.9848
# Epoch 50/50
# 1088/1088 [==============================] - 5s 4ms/step - loss: 0.0359 - accuracy: 0.9930 - val_loss: 0.1126 - val_accuracy: 0.9864

# %%
heramb.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 32)        832
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 26, 26, 64)        18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 11, 11, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1600)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               409856
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 43)                11051
# =================================================================
# Total params: 477,163
# Trainable params: 477,163
# Non-trainable params: 0
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Training Loss', 'Validation Loss'], loc='best')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='best')
plt.show()

# %%
score = heramb.evaluate(X_test_gray_norm, y_test)
print('Test Accuracy: {}'.format(score[1]))
# Out:
# 395/395 [==============================] - 1s 2ms/step - loss: 0.3310 - accuracy: 0.9730
# Test Accuracy: 0.9730007648468018

# %% [markdown]
# # #Attach a screen shot of your results as proof below this cell

# %% [markdown]
# Test Dataset Accuracy

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Other helper functions
#
# > Indented block

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'bo', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# %%
plt.plot(epochs, loss, 'ro', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()

# %%
import numpy as np
rounded_labels=np.argmax(y_test, axis=1)
rounded_labels[1]
# Out:
# 1

# %%
predict_class = heramb.predict_classes(X_test_gray_norm)
# Out:
# WARNING:tensorflow:From <ipython-input-33-09fcd0a282f4>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

plt.figure(figsize=(25, 25))
cm = confusion_matrix(rounded_labels, predict_class)
hm = sns.heatmap(cm, annot=True, square=True, linewidths=1, cmap='Blues')
plt.show(hm)

# %%
L = 5
W = 5

fig, axes = plt.subplots(L, W, figsize = (12, 12))
axes = axes.ravel()

for i in np.arange(0, L*W):
    axes[i].imshow(X_test[i])
    axes[i].set_title('Prediction = {}\n True = {}'.format(predict_class[i], rounded_labels[i]))
    axes[i].axis('off')

plt.subplots_adjust(wspace = 1)
