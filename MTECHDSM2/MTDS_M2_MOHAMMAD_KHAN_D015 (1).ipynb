# %% [markdown]
# # TASK #2: MOUNT DRIVE AND IMPORT LIBRARIES/DATASETS

# %% [markdown]
# - In this case study, we want to classify images of traffic signs using deep Convolutional Neural Networks (CNNs).
# - The dataset consists of 43 different classes of images.
# - Classes are as listed below:
#   - 0 = Speed limit (20km/h)
#   - 1 = Speed limit (30km/h)
#   - 2 = Speed limit (50km/h)
#   - 3 = Speed limit (60km/h)
#   - 4 = Speed limit (70km/h)
#   - 5 = Speed limit (80km/h)
#   - 6 = End of speed limit (80km/h)
#   - 7 = Speed limit (100km/h)
#   - 8 = Speed limit (120km/h)
#   - 9 = No passing
#   - 10 = No passing for vehicles over 3.5 metric tons
#   - 11 = Right-of-way at the next intersection
#   - 12 = Priority road
#   - 13 = Yield
#   - 14 = Stop
#   - 15 = No vehicles
#   - 16 = Vehicles over 3.5 metric tons prohibited
#   - 17 = No entry
#   - 18 = General caution
#   - 19 = Dangerous curve to the left
#   - 20 = Dangerous curve to the right
#   - 21 = Double curve
#   - 22 = Bumpy road
#   - 23 = Slippery road
#   - 24 = Road narrows on the right
#   - 25 = Road work
#   - 26 = Traffic signals
#   - 27 = Pedestrians
#   - 28 = Children crossing
#   - 29 = Bicycles crossing
#   - 30 = Beware of ice/snow
#   - 31 = Wild animals crossing
#   - 32 = End of all speed and passing limits
#   - 33 = Turn right ahead
#   - 34 = Turn left ahead
#   - 35 = Ahead only
#   - 36 = Go straight or right
#   - 37 = Go straight or left
#   - 38 = Keep right
#   - 39 = Keep left
#   - 40 = Roundabout mandatory
#   - 41 = End of no passing
#   - 42 = End of no passing by vehicles over 3.5 metric tons
#
# - Citation
# J. Stallkamp, M. Schlipsing, J. Salmen, and C. Igel. The German Traffic Sign Recognition Benchmark: A multi-class classification competition. In Proceedings of the IEEE International Joint Conference on Neural Networks, pages 1453–1460. 2011.
# @inproceedings{Stallkamp-IJCNN-2011, author = {Johannes Stallkamp and Marc Schlipsing and Jan Salmen and Christian Igel}, booktitle = {IEEE International Joint Conference on Neural Networks}, title = {The {G}erman {T}raffic {S}ign {R}ecognition {B}enchmark: A multi-class classification competition}, year = {2011}, pages = {1453--1460} }

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import pandas as pd
import seaborn as sns
import pickle
import random

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq" -O train.p && rm -rf /tmp/cookies.txt
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1zJxB1YzBYuImaHBSxWGN-ZXPDRYN_CTX' -O valid.p
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1jZhZpEZkYFaaPPAwfd1cB8e-FK0aoeC0' -O test.p
# Out:
# --2020-09-29 08:25:17--  https://docs.google.com/uc?export=download&confirm=Gr5M&id=1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq
# Resolving docs.google.com (docs.google.com)... 74.125.197.100, 74.125.197.138, 74.125.197.102, ...
# Connecting to docs.google.com (docs.google.com)|74.125.197.100|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0g-bc-docs.googleusercontent.com/docs/securesc/n0tf6c2jevg5sophglva5il2imieag3b/b14h7nmosktohveknlhsg2g4d6r8g1cd/1601367900000/17242455652310080862/05349124237557221993Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e=download [following]
# --2020-09-29 08:25:17--  https://doc-0g-bc-docs.googleusercontent.com/docs/securesc/n0tf6c2jevg5sophglva5il2imieag3b/b14h7nmosktohveknlhsg2g4d6r8g1cd/1601367900000/17242455652310080862/05349124237557221993Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e=download
# Resolving doc-0g-bc-docs.googleusercontent.com (doc-0g-bc-docs.googleusercontent.com)... 74.125.197.132, 2607:f8b0:400e:c03::84
# Connecting to doc-0g-bc-docs.googleusercontent.com (doc-0g-bc-docs.googleusercontent.com)|74.125.197.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=b2s9qqnfk99mc&continue=https://doc-0g-bc-docs.googleusercontent.com/docs/securesc/n0tf6c2jevg5sophglva5il2imieag3b/b14h7nmosktohveknlhsg2g4d6r8g1cd/1601367900000/17242455652310080862/05349124237557221993Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e%3Ddownload&hash=86ibnn1eea0r3rf4eou6ml919qhu7mt9 [following]
# --2020-09-29 08:25:17--  https://docs.google.com/nonceSigner?nonce=b2s9qqnfk99mc&continue=https://doc-0g-bc-docs.googleusercontent.com/docs/securesc/n0tf6c2jevg5sophglva5il2imieag3b/b14h7nmosktohveknlhsg2g4d6r8g1cd/1601367900000/17242455652310080862/05349124237557221993Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e%3Ddownload&hash=86ibnn1eea0r3rf4eou6ml919qhu7mt9
# Connecting to docs.google.com (docs.google.com)|74.125.197.100|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-0g-bc-docs.googleusercontent.com/docs/securesc/n0tf6c2jevg5sophglva5il2imieag3b/b14h7nmosktohveknlhsg2g4d6r8g1cd/1601367900000/17242455652310080862/05349124237557221993Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e=download&nonce=b2s9qqnfk99mc&user=05349124237557221993Z&hash=o27r815ofrj3dhpl4d16qpiileftmvq6 [following]
# --2020-09-29 08:25:17--  https://doc-0g-bc-docs.googleusercontent.com/docs/securesc/n0tf6c2jevg5sophglva5il2imieag3b/b14h7nmosktohveknlhsg2g4d6r8g1cd/1601367900000/17242455652310080862/05349124237557221993Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e=download&nonce=b2s9qqnfk99mc&user=05349124237557221993Z&hash=o27r815ofrj3dhpl4d16qpiileftmvq6
# Connecting to doc-0g-bc-docs.googleusercontent.com (doc-0g-bc-docs.googleusercontent.com)|74.125.197.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/x-pascal]
# Saving to: ‘train.p’
#
# train.p                 [   <=>              ] 102.18M   207MB/s    in 0.5s
#
# 2020-09-29 08:25:18 (207 MB/s) - ‘train.p’ saved [107146452]
#
# --2020-09-29 08:25:18--  https://docs.google.com/uc?export=download&id=1zJxB1YzBYuImaHBSxWGN-ZXPDRYN_CTX
# Resolving docs.google.com (docs.google.com)... 74.125.197.113, 74.125.197.100, 74.125.197.101, ...
# Connecting to docs.google.com (docs.google.com)|74.125.197.113|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0c-7s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/6bkdpkb400d7r3gad1cc2aguqqjlkrdb/1601367900000/17242455652310080862/*/1zJxB1YzBYuImaHBSxWGN-ZXPDRYN_CTX?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2020-09-29 08:25:19--  https://doc-0c-7s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/6bkdpkb400d7r3gad1cc2aguqqjlkrdb/1601367900000/17242455652310080862/*/1zJxB1YzBYuImaHBSxWGN-ZXPDRYN_CTX?e=download
# Resolving doc-0c-7s-docs.googleusercontent.com (doc-0c-7s-docs.googleusercontent.com)... 74.125.197.132, 2607:f8b0:400e:c03::84
# Connecting to doc-0c-7s-docs.googleusercontent.com (doc-0c-7s-docs.googleusercontent.com)|74.125.197.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/x-pascal]
# Saving to: ‘valid.p’
#
# valid.p                 [ <=>                ]  12.95M  --.-KB/s    in 0.08s
#
# 2020-09-29 08:25:19 (162 MB/s) - ‘valid.p’ saved [13578712]
#
# --2020-09-29 08:25:19--  https://docs.google.com/uc?export=download&id=1jZhZpEZkYFaaPPAwfd1cB8e-FK0aoeC0
# Resolving docs.google.com (docs.google.com)... 74.125.195.138, 74.125.195.139, 74.125.195.102, ...
# Connecting to docs.google.com (docs.google.com)|74.125.195.138|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0g-7s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/ial487ekcif27pa0nis1r51ak0o888sb/1601367900000/17242455652310080862/*/1jZhZpEZkYFaaPPAwfd1cB8e-FK0aoeC0?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2020-09-29 08:25:20--  https://doc-0g-7s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/ial487ekcif27pa0nis1r51ak0o888sb/1601367900000/17242455652310080862/*/1jZhZpEZkYFaaPPAwfd1cB8e-FK0aoeC0?e=download
# Resolving doc-0g-7s-docs.googleusercontent.com (doc-0g-7s-docs.googleusercontent.com)... 74.125.197.132, 2607:f8b0:400e:c03::84
# Connecting to doc-0g-7s-docs.googleusercontent.com (doc-0g-7s-docs.googleusercontent.com)|74.125.197.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/x-pascal]
# Saving to: ‘test.p’
#
# test.p                  [  <=>               ]  37.09M   136MB/s    in 0.3s
#
# 2020-09-29 08:25:20 (136 MB/s) - ‘test.p’ saved [38888118]

# %%
with open("/content/train.p", mode='rb') as training_data:
  train = pickle.load(training_data)
with open("/content/valid.p", mode='rb') as validation_data:
  valid = pickle.load(validation_data)
with open("/content/test.p", mode='rb') as testing_data:
  test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']
X_validation, y_validation = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
X_train.shape
# Out:
# (34799, 32, 32, 3)

# %%
y_train.shape
# Out:
# (34799,)

# %%
X_validation.shape
# Out:
# (4410, 32, 32, 3)

# %%
y_validation.shape
# Out:
# (4410,)

# %%
X_test.shape
# Out:
# (12630, 32, 32, 3)

# %%
y_test.shape
# Out:
# (12630,)

# %% [markdown]
# # TASK #3: PERFROM IMAGES VISUALIZATION

# %%
i = np.random.randint(1, len(X_train))
plt.imshow(X_train[i])
y_train[i]
# Out:
# 9

# %%
# Let's view more images in a grid format
# Define the dimensions of the plot grid 
W_grid = 5
L_grid = 5

# fig, axes = plt.subplots(L_grid, W_grid)
# subplot return the figure object and axes object
# we can use the axes object to plot specific figures at various locations

fig, axes = plt.subplots(L_grid, W_grid, figsize = (10,10))

axes = axes.ravel() # flaten the 15 x 15 matrix into 225 array

n_training = len(X_train) # get the length of the training dataset

# Select a random number from 0 to n_training
for i in np.arange(0, W_grid * L_grid): # create evenly spaces variables 

    # Select a random number
    index = np.random.randint(0, n_training)
    # read and display an image with the selected index    
    axes[i].imshow( X_train[index])
    axes[i].set_title(y_train[index], fontsize = 15)
    axes[i].axis('off')

plt.subplots_adjust(hspace=0.4)

# %% [markdown]
# # TASK #4: CONVERT IMAGES TO GRAYSCALE AND PERFORM NORMALIZATION

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %% [markdown]
# #Since its an RGB image, so it means that you have add r with g with b and then divide it by 3 to get your desired grayscale image. Its done in this way. If you have an color image like the image shown above and you want to convert it into grayscale using average method.

# %%
X_train_gray = np.sum(X_train/3, axis = 3, keepdims = True)
X_test_gray = np.sum(X_test/3, axis = 3, keepdims = True)
X_validation_gray = np.sum(X_validation/3, axis = 3, keepdims = True)

# %%
X_train_gray.shape
# Out:
# (34799, 32, 32, 1)

# %%
X_test_gray.shape
# Out:
# (12630, 32, 32, 1)

# %%
X_validation_gray.shape
# Out:
# (4410, 32, 32, 1)

# %%
X_train_gray_norm = (X_train_gray - 128)/128
X_test_gray_norm = (X_test_gray - 128)/128
X_validation_gray_norm = (X_validation_gray - 128)/128

# %%
i = random.randint(1, len(X_train_gray))
plt.imshow(X_train_gray[i].squeeze(), cmap = 'gray')
plt.figure()
plt.imshow(X_train[i])
plt.figure()
plt.imshow(X_train_gray_norm[i].squeeze(), cmap = 'gray')

# %% [markdown]
# #Building the model

# %% [markdown]
# #Use this space for coding

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout

CNN = Sequential()

CNN.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu', input_shape=X_train_gray_norm.shape[1:]))

CNN.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
CNN.add(MaxPool2D(pool_size=(2, 2)))
CNN.add(Dropout(rate=0.25))

CNN.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
CNN.add(MaxPool2D(pool_size=(2, 2)))
CNN.add(Dropout(rate=0.25))

CNN.add(Flatten())

CNN.add(Dense(256, activation='relu'))
CNN.add(Dropout(rate=0.5))
CNN.add(Dense(43, activation='softmax'))

CNN.compile(
    loss='categorical_crossentropy', 
    optimizer='adam', 
    metrics=['accuracy']
)

# %%
CNN.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 28, 28, 32)        832
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 26, 26, 64)        18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 11, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               409856
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 43)                11051
# =================================================================
# Total params: 477,163
# Trainable params: 477,163
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = CNN.fit(X_train_gray_norm,y_train,batch_size=500,epochs = 50,verbose=1,validation_data=(X_validation_gray_norm,y_validation))
# Out:
# Epoch 1/50
#  1/70 [..............................] - ETA: 1s - loss: 0.0307 - accuracy: 0.9900WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0134s vs `on_train_batch_end` time: 0.0209s). Check your callbacks.
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0322 - accuracy: 0.9895 - val_loss: 0.0544 - val_accuracy: 0.9880
# Epoch 2/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0297 - accuracy: 0.9908 - val_loss: 0.0579 - val_accuracy: 0.9864
# Epoch 3/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0291 - accuracy: 0.9911 - val_loss: 0.0624 - val_accuracy: 0.9859
# Epoch 4/50
# 70/70 [==============================] - 2s 28ms/step - loss: 0.0261 - accuracy: 0.9917 - val_loss: 0.0563 - val_accuracy: 0.9878
# Epoch 5/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0249 - accuracy: 0.9920 - val_loss: 0.0550 - val_accuracy: 0.9880
# Epoch 6/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0232 - accuracy: 0.9923 - val_loss: 0.0520 - val_accuracy: 0.9880
# Epoch 7/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0222 - accuracy: 0.9930 - val_loss: 0.0490 - val_accuracy: 0.9893
# Epoch 8/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0215 - accuracy: 0.9932 - val_loss: 0.0593 - val_accuracy: 0.9857
# Epoch 9/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0226 - accuracy: 0.9928 - val_loss: 0.0618 - val_accuracy: 0.9850
# Epoch 10/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0181 - accuracy: 0.9939 - val_loss: 0.0512 - val_accuracy: 0.9882
# Epoch 11/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0213 - accuracy: 0.9933 - val_loss: 0.0631 - val_accuracy: 0.9868
# Epoch 12/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0210 - accuracy: 0.9938 - val_loss: 0.0613 - val_accuracy: 0.9882
# Epoch 13/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0230 - accuracy: 0.9925 - val_loss: 0.0523 - val_accuracy: 0.9866
# Epoch 14/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0174 - accuracy: 0.9944 - val_loss: 0.0600 - val_accuracy: 0.9871
# Epoch 15/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0158 - accuracy: 0.9950 - val_loss: 0.0550 - val_accuracy: 0.9893
# Epoch 16/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0176 - accuracy: 0.9943 - val_loss: 0.0459 - val_accuracy: 0.9893
# Epoch 17/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0159 - accuracy: 0.9948 - val_loss: 0.0585 - val_accuracy: 0.9884
# Epoch 18/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0146 - accuracy: 0.9953 - val_loss: 0.0532 - val_accuracy: 0.9891
# Epoch 19/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0162 - accuracy: 0.9946 - val_loss: 0.0656 - val_accuracy: 0.9846
# Epoch 20/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0153 - accuracy: 0.9949 - val_loss: 0.0522 - val_accuracy: 0.9891
# Epoch 21/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0166 - accuracy: 0.9945 - val_loss: 0.0680 - val_accuracy: 0.9875
# Epoch 22/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0183 - accuracy: 0.9943 - val_loss: 0.0560 - val_accuracy: 0.9866
# Epoch 23/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0150 - accuracy: 0.9951 - val_loss: 0.0582 - val_accuracy: 0.9884
# Epoch 24/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0135 - accuracy: 0.9954 - val_loss: 0.0632 - val_accuracy: 0.9868
# Epoch 25/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0124 - accuracy: 0.9956 - val_loss: 0.0450 - val_accuracy: 0.9902
# Epoch 26/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0124 - accuracy: 0.9957 - val_loss: 0.0540 - val_accuracy: 0.9900
# Epoch 27/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0129 - accuracy: 0.9957 - val_loss: 0.0497 - val_accuracy: 0.9905
# Epoch 28/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0143 - accuracy: 0.9953 - val_loss: 0.0545 - val_accuracy: 0.9880
# Epoch 29/50
# 70/70 [==============================] - 2s 30ms/step - loss: 0.0123 - accuracy: 0.9966 - val_loss: 0.0531 - val_accuracy: 0.9898
# Epoch 30/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0125 - accuracy: 0.9958 - val_loss: 0.0655 - val_accuracy: 0.9875
# Epoch 31/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0115 - accuracy: 0.9965 - val_loss: 0.0611 - val_accuracy: 0.9880
# Epoch 32/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0110 - accuracy: 0.9965 - val_loss: 0.0780 - val_accuracy: 0.9825
# Epoch 33/50
# 70/70 [==============================] - 2s 30ms/step - loss: 0.0117 - accuracy: 0.9965 - val_loss: 0.0519 - val_accuracy: 0.9905
# Epoch 34/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0102 - accuracy: 0.9966 - val_loss: 0.0626 - val_accuracy: 0.9850
# Epoch 35/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0121 - accuracy: 0.9960 - val_loss: 0.0567 - val_accuracy: 0.9902
# Epoch 36/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0117 - accuracy: 0.9966 - val_loss: 0.0517 - val_accuracy: 0.9880
# Epoch 37/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0102 - accuracy: 0.9971 - val_loss: 0.0618 - val_accuracy: 0.9905
# Epoch 38/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0125 - accuracy: 0.9959 - val_loss: 0.0608 - val_accuracy: 0.9909
# Epoch 39/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0118 - accuracy: 0.9966 - val_loss: 0.0616 - val_accuracy: 0.9882
# Epoch 40/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0104 - accuracy: 0.9966 - val_loss: 0.0716 - val_accuracy: 0.9828
# Epoch 41/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0113 - accuracy: 0.9964 - val_loss: 0.0500 - val_accuracy: 0.9905
# Epoch 42/50
# 70/70 [==============================] - 2s 30ms/step - loss: 0.0111 - accuracy: 0.9961 - val_loss: 0.0717 - val_accuracy: 0.9819
# Epoch 43/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0114 - accuracy: 0.9962 - val_loss: 0.0592 - val_accuracy: 0.9878
# Epoch 44/50
# 70/70 [==============================] - 2s 30ms/step - loss: 0.0097 - accuracy: 0.9972 - val_loss: 0.0736 - val_accuracy: 0.9853
# Epoch 45/50
# 70/70 [==============================] - 2s 30ms/step - loss: 0.0095 - accuracy: 0.9971 - val_loss: 0.0847 - val_accuracy: 0.9855
# Epoch 46/50
# 70/70 [==============================] - 2s 30ms/step - loss: 0.0099 - accuracy: 0.9966 - val_loss: 0.0711 - val_accuracy: 0.9857
# Epoch 47/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0110 - accuracy: 0.9965 - val_loss: 0.0583 - val_accuracy: 0.9902
# Epoch 48/50
# 70/70 [==============================] - 2s 30ms/step - loss: 0.0109 - accuracy: 0.9961 - val_loss: 0.0653 - val_accuracy: 0.9893
# Epoch 49/50
# 70/70 [==============================] - 2s 30ms/step - loss: 0.0081 - accuracy: 0.9976 - val_loss: 0.0594 - val_accuracy: 0.9907
# Epoch 50/50
# 70/70 [==============================] - 2s 29ms/step - loss: 0.0084 - accuracy: 0.9974 - val_loss: 0.0599 - val_accuracy: 0.9868

# %%
score = CNN.evaluate(X_test_gray_norm, y_test)
print('Test Accuracy: {}'.format(score[1]))
# Out:
# 395/395 [==============================] - 1s 2ms/step - loss: 0.1601 - accuracy: 0.9715
# Test Accuracy: 0.9714964628219604

# %% [markdown]
# #Attach a screen shot of your results as proof below this cell

# %% [markdown]
# ![Screenshot (73).png](data:image/png;base64,...)

# %% [markdown]
# #Other helper functions

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'bo', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# %%
plt.plot(epochs, loss, 'ro', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()

# %%
predicted_classes = CNN.predict_classes(X_test_gray_norm)
y_true = y_test
# Out:
# WARNING:tensorflow:From <ipython-input-56-c030e79a0393>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, predicted_classes)
plt.figure(figsize = (25, 25))
sns.heatmap(cm, annot = True)

# %%
L = 5
W = 5

fig, axes = plt.subplots(L, W, figsize = (12, 12))
axes = axes.ravel()

for i in np.arange(0, L*W):
    axes[i].imshow(X_test[i])
    axes[i].set_title('Prediction = {}\n True = {}'.format(predicted_classes[i], y_true[i]))
    axes[i].axis('off')

plt.subplots_adjust(wspace = 1)
