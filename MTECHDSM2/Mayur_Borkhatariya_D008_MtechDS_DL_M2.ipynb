# %%
import keras
import tensorflow as tf

keras.backend.clear_session()

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import pandas as pd
import seaborn as sns
import pickle
import random
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq" -O train.p && rm -rf /tmp/cookies.txt
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1zJxB1YzBYuImaHBSxWGN-ZXPDRYN_CTX' -O valid.p
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1jZhZpEZkYFaaPPAwfd1cB8e-FK0aoeC0' -O test.p
# Out:
# --2020-09-29 08:52:08--  https://docs.google.com/uc?export=download&confirm=zqnO&id=1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq
# Resolving docs.google.com (docs.google.com)... 74.125.203.139, 74.125.203.102, 74.125.203.113, ...
# Connecting to docs.google.com (docs.google.com)|74.125.203.139|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0o-8k-docs.googleusercontent.com/docs/securesc/84o3gqlckrbbb1egngct0l0is19u7rvg/bkbo78evirgcg5n9kkahug92u16cld6t/1601369475000/17242455652310080862/17632937708758554198Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e=download [following]
# --2020-09-29 08:52:09--  https://doc-0o-8k-docs.googleusercontent.com/docs/securesc/84o3gqlckrbbb1egngct0l0is19u7rvg/bkbo78evirgcg5n9kkahug92u16cld6t/1601369475000/17242455652310080862/17632937708758554198Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e=download
# Resolving doc-0o-8k-docs.googleusercontent.com (doc-0o-8k-docs.googleusercontent.com)... 64.233.189.132, 2404:6800:4008:c07::84
# Connecting to doc-0o-8k-docs.googleusercontent.com (doc-0o-8k-docs.googleusercontent.com)|64.233.189.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=jv0t1gfqhv3oi&continue=https://doc-0o-8k-docs.googleusercontent.com/docs/securesc/84o3gqlckrbbb1egngct0l0is19u7rvg/bkbo78evirgcg5n9kkahug92u16cld6t/1601369475000/17242455652310080862/17632937708758554198Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e%3Ddownload&hash=anuben4rftdqm9vpqohhnemsrq6ddra2 [following]
# --2020-09-29 08:52:09--  https://docs.google.com/nonceSigner?nonce=jv0t1gfqhv3oi&continue=https://doc-0o-8k-docs.googleusercontent.com/docs/securesc/84o3gqlckrbbb1egngct0l0is19u7rvg/bkbo78evirgcg5n9kkahug92u16cld6t/1601369475000/17242455652310080862/17632937708758554198Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e%3Ddownload&hash=anuben4rftdqm9vpqohhnemsrq6ddra2
# Connecting to docs.google.com (docs.google.com)|74.125.203.139|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-0o-8k-docs.googleusercontent.com/docs/securesc/84o3gqlckrbbb1egngct0l0is19u7rvg/bkbo78evirgcg5n9kkahug92u16cld6t/1601369475000/17242455652310080862/17632937708758554198Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e=download&nonce=jv0t1gfqhv3oi&user=17632937708758554198Z&hash=qirlv7nshe2o7mkskqkqtlmuvguf9qej [following]
# --2020-09-29 08:52:09--  https://doc-0o-8k-docs.googleusercontent.com/docs/securesc/84o3gqlckrbbb1egngct0l0is19u7rvg/bkbo78evirgcg5n9kkahug92u16cld6t/1601369475000/17242455652310080862/17632937708758554198Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e=download&nonce=jv0t1gfqhv3oi&user=17632937708758554198Z&hash=qirlv7nshe2o7mkskqkqtlmuvguf9qej
# Connecting to doc-0o-8k-docs.googleusercontent.com (doc-0o-8k-docs.googleusercontent.com)|64.233.189.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/x-pascal]
# Saving to: ‘train.p’
#
# train.p                 [   <=>              ] 102.18M   181MB/s    in 0.6s
#
# 2020-09-29 08:52:10 (181 MB/s) - ‘train.p’ saved [107146452]
#
# --2020-09-29 08:52:10--  https://docs.google.com/uc?export=download&id=1zJxB1YzBYuImaHBSxWGN-ZXPDRYN_CTX
# Resolving docs.google.com (docs.google.com)... 64.233.187.138, 64.233.187.113, 64.233.187.100, ...
# Connecting to docs.google.com (docs.google.com)|64.233.187.138|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0c-7s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/tpdo7h1kfelnrdfhi9kk816jj9vkqf6r/1601369475000/17242455652310080862/*/1zJxB1YzBYuImaHBSxWGN-ZXPDRYN_CTX?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2020-09-29 08:52:11--  https://doc-0c-7s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/tpdo7h1kfelnrdfhi9kk816jj9vkqf6r/1601369475000/17242455652310080862/*/1zJxB1YzBYuImaHBSxWGN-ZXPDRYN_CTX?e=download
# Resolving doc-0c-7s-docs.googleusercontent.com (doc-0c-7s-docs.googleusercontent.com)... 64.233.189.132, 2404:6800:4008:c07::84
# Connecting to doc-0c-7s-docs.googleusercontent.com (doc-0c-7s-docs.googleusercontent.com)|64.233.189.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/x-pascal]
# Saving to: ‘valid.p’
#
# valid.p                 [ <=>                ]  12.95M  --.-KB/s    in 0.1s
#
# 2020-09-29 08:52:11 (113 MB/s) - ‘valid.p’ saved [13578712]
#
# --2020-09-29 08:52:11--  https://docs.google.com/uc?export=download&id=1jZhZpEZkYFaaPPAwfd1cB8e-FK0aoeC0
# Resolving docs.google.com (docs.google.com)... 64.233.189.113, 64.233.189.102, 64.233.189.138, ...
# Connecting to docs.google.com (docs.google.com)|64.233.189.113|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0g-7s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/da4m25v172va0jgvjk1j2cg81blgdlah/1601369475000/17242455652310080862/*/1jZhZpEZkYFaaPPAwfd1cB8e-FK0aoeC0?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2020-09-29 08:52:12--  https://doc-0g-7s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/da4m25v172va0jgvjk1j2cg81blgdlah/1601369475000/17242455652310080862/*/1jZhZpEZkYFaaPPAwfd1cB8e-FK0aoeC0?e=download
# Resolving doc-0g-7s-docs.googleusercontent.com (doc-0g-7s-docs.googleusercontent.com)... 64.233.189.132, 2404:6800:4008:c07::84
# Connecting to doc-0g-7s-docs.googleusercontent.com (doc-0g-7s-docs.googleusercontent.com)|64.233.189.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/x-pascal]
# Saving to: ‘test.p’
#
# test.p                  [  <=>               ]  37.09M  68.3MB/s    in 0.5s
#
# 2020-09-29 08:52:13 (68.3 MB/s) - ‘test.p’ saved [38888118]

# %%
with open("/content/train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("/content/valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("/content/test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']
X_validation, y_validation = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
X_train.shape, y_train.shape
# Out:
# ((34799, 32, 32, 3), (34799,))

# %%
X_validation.shape,y_validation.shape
# Out:
# ((4410, 32, 32, 3), (4410,))

# %%
X_test.shape,y_test.shape
# Out:
# ((12630, 32, 32, 3), (12630,))

# %%
i = np.random.randint(1, len(X_train))
plt.imshow(X_train[i])
y_train[i]
# Out:
# 40

# %%
# Let's view more images in a grid format
# Define the dimensions of the plot grid 
W_grid = 5
L_grid = 5

# fig, axes = plt.subplots(L_grid, W_grid)
# subplot return the figure object and axes object
# we can use the axes object to plot specific figures at various locations

fig, axes = plt.subplots(L_grid, W_grid, figsize = (10,10))

axes = axes.ravel() # flaten the 15 x 15 matrix into 225 array

n_training = len(X_train) # get the length of the training dataset

# Select a random number from 0 to n_training
for i in np.arange(0, W_grid * L_grid): # create evenly spaces variables 

    # Select a random number
    index = np.random.randint(0, n_training)
    # read and display an image with the selected index    
    axes[i].imshow( X_train[index])
    axes[i].set_title(y_train[index], fontsize = 15)
    axes[i].axis('off')

plt.subplots_adjust(hspace=0.4)

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %%
X_train_gray = np.sum(X_train/3, axis = 3, keepdims = True)
X_test_gray = np.sum(X_test/3, axis = 3, keepdims = True)
X_validation_gray = np.sum(X_validation/3, axis = 3, keepdims = True)

# %%
X_train_gray.shape,X_test_gray.shape,X_validation_gray.shape
# Out:
# ((34799, 32, 32, 1), (12630, 32, 32, 1), (4410, 32, 32, 1))

# %%
X_train_gray_norm = (X_train_gray - 128)/128
X_test_gray_norm = (X_test_gray - 128)/128
X_validation_gray_norm = (X_validation_gray - 128)/128

# %%
i = random.randint(1, len(X_train_gray))
plt.imshow(X_train_gray[i].squeeze(), cmap = 'gray')
plt.figure()
plt.imshow(X_train[i])
plt.figure()
plt.imshow(X_train_gray_norm[i].squeeze(), cmap = 'gray')

# %%
#Using one hote encoding for the train and validation labels
from keras.utils import to_categorical
y_train = to_categorical(y_train, 43)
y_validation = to_categorical(y_validation, 43)
y_test=to_categorical(y_test, 43)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout

model = Sequential()
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu', input_shape=X_train_gray_norm.shape[1:]))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(rate=0.5))
model.add(Dense(43, activation='softmax'))

#Compilation of the model
model.compile(
    loss='categorical_crossentropy', 
    optimizer='adam', 
    metrics=['accuracy']
)

# %%
#using ten epochs for the training and saving the accuracy for each epoch
epochs = 20
history = model.fit(X_train_gray_norm, y_train, batch_size=32, epochs=epochs,
validation_data=(X_validation_gray_norm, y_validation))
# Out:
# Epoch 1/20
# 1088/1088 [==============================] - 10s 9ms/step - loss: 0.9159 - accuracy: 0.7422 - val_loss: 0.1499 - val_accuracy: 0.9562
# Epoch 2/20
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.1701 - accuracy: 0.9495 - val_loss: 0.0897 - val_accuracy: 0.9728
# Epoch 3/20
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.1095 - accuracy: 0.9671 - val_loss: 0.1115 - val_accuracy: 0.9723
# Epoch 4/20
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0865 - accuracy: 0.9732 - val_loss: 0.0729 - val_accuracy: 0.9778
# Epoch 5/20
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0682 - accuracy: 0.9792 - val_loss: 0.0603 - val_accuracy: 0.9855
# Epoch 6/20
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0708 - accuracy: 0.9780 - val_loss: 0.0763 - val_accuracy: 0.9773
# Epoch 7/20
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0578 - accuracy: 0.9822 - val_loss: 0.0615 - val_accuracy: 0.9825
# Epoch 8/20
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0547 - accuracy: 0.9833 - val_loss: 0.0458 - val_accuracy: 0.9875
# Epoch 9/20
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0485 - accuracy: 0.9852 - val_loss: 0.0791 - val_accuracy: 0.9812
# Epoch 10/20
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0585 - accuracy: 0.9818 - val_loss: 0.1138 - val_accuracy: 0.9649
# Epoch 11/20
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0443 - accuracy: 0.9865 - val_loss: 0.0873 - val_accuracy: 0.9760
# Epoch 12/20
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0435 - accuracy: 0.9872 - val_loss: 0.1240 - val_accuracy: 0.9769
# Epoch 13/20
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0461 - accuracy: 0.9857 - val_loss: 0.1193 - val_accuracy: 0.9769
# Epoch 14/20
# 1088/1088 [==============================] - 10s 9ms/step - loss: 0.0441 - accuracy: 0.9868 - val_loss: 0.1152 - val_accuracy: 0.9757
# Epoch 15/20
# 1088/1088 [==============================] - 9s 9ms/step - loss: 0.0421 - accuracy: 0.9878 - val_loss: 0.0969 - val_accuracy: 0.9814
# Epoch 16/20
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0380 - accuracy: 0.9888 - val_loss: 0.1232 - val_accuracy: 0.9778
# Epoch 17/20
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0376 - accuracy: 0.9890 - val_loss: 0.1223 - val_accuracy: 0.9794
# Epoch 18/20
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0367 - accuracy: 0.9891 - val_loss: 0.0860 - val_accuracy: 0.9839
# Epoch 19/20
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0469 - accuracy: 0.9878 - val_loss: 0.0552 - val_accuracy: 0.9868
# Epoch 20/20
# 1088/1088 [==============================] - 9s 8ms/step - loss: 0.0386 - accuracy: 0.9897 - val_loss: 0.1478 - val_accuracy: 0.9707

# %%
score = model.evaluate(X_test_gray_norm, y_test)
print('Test Accuracy: {}'.format(score[1]))
# Out:
# 395/395 [==============================] - 2s 4ms/step - loss: 0.2401 - accuracy: 0.9615
# Test Accuracy: 0.9615201950073242

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **APPLYING DATA AUGMENTATION**

# %%
from keras.preprocessing.image import ImageDataGenerator
 
datagen = ImageDataGenerator(width_shift_range=0.1,
                            height_shift_range=0.1,
                            zoom_range=0.3,
                            shear_range=0.1,
                            rotation_range=9.)
 
datagen.fit(X_train)
batches = datagen.flow(X_train_gray_norm, y_train, batch_size = 32)
X_batch, y_batch = next(batches)
 
fig, axs = plt.subplots(1, 15, figsize=(20, 5))
fig.tight_layout()
 
for i in range(15):
    axs[i].imshow(X_batch[i].reshape(32, 32))
    axs[i].axis("off")
 
print(X_batch.shape)
# Out:
# (32, 32, 32, 1)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout,MaxPooling2D
from keras.optimizers import Adam

def modified_model():
  model = Sequential()
  model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu', input_shape=X_train_gray_norm.shape[1:]))
  model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
  model.add(MaxPool2D(pool_size=(2, 2)))
  model.add(Dropout(rate=0.25))
  model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
  model.add(MaxPool2D(pool_size=(2, 2)))
  model.add(Dropout(rate=0.25))
  model.add(Flatten())
  model.add(Dense(256, activation='relu'))
  model.add(Dropout(rate=0.5))
  model.add(Dense(43, activation='softmax'))

  #Compilation of the model
  model.compile(
    loss='categorical_crossentropy', 
    optimizer='adam', 
    metrics=['accuracy']
  )
  return model

# %%
model = modified_model()
print(model.summary())
 
history_new = model.fit_generator(datagen.flow(X_train_gray_norm, y_train, batch_size=32),
                            epochs=20,
                            validation_data=(X_validation_gray_norm, y_validation))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 28, 28, 32)        832
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 26, 26, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 11, 11, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               409856
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 43)                11051
# =================================================================
# Total params: 477,163
# Trainable params: 477,163
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:From <ipython-input-22-ca4a449e7e60>:6: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/20
# 1088/1088 [==============================] - 21s 19ms/step - loss: 2.0293 - accuracy: 0.4300 - val_loss: 0.4139 - val_accuracy: 0.8542
# Epoch 2/20
# 1088/1088 [==============================] - 20s 19ms/step - loss: 0.7472 - accuracy: 0.7713 - val_loss: 0.1560 - val_accuracy: 0.9624
# Epoch 3/20
# 1088/1088 [==============================] - 20s 19ms/step - loss: 0.4853 - accuracy: 0.8526 - val_loss: 0.0994 - val_accuracy: 0.9737
# Epoch 4/20
# 1088/1088 [==============================] - 20s 19ms/step - loss: 0.3772 - accuracy: 0.8828 - val_loss: 0.0686 - val_accuracy: 0.9803
# Epoch 5/20
# 1088/1088 [==============================] - 20s 19ms/step - loss: 0.3191 - accuracy: 0.9021 - val_loss: 0.0570 - val_accuracy: 0.9825
# Epoch 6/20
# 1088/1088 [==============================] - 20s 19ms/step - loss: 0.2885 - accuracy: 0.9131 - val_loss: 0.0567 - val_accuracy: 0.9794
# Epoch 7/20
# 1088/1088 [==============================] - 20s 19ms/step - loss: 0.2524 - accuracy: 0.9218 - val_loss: 0.0414 - val_accuracy: 0.9889
# Epoch 8/20
# 1088/1088 [==============================] - 20s 19ms/step - loss: 0.2270 - accuracy: 0.9305 - val_loss: 0.0479 - val_accuracy: 0.9875
# Epoch 9/20
# 1088/1088 [==============================] - 20s 19ms/step - loss: 0.2100 - accuracy: 0.9355 - val_loss: 0.0364 - val_accuracy: 0.9882
# Epoch 10/20
# 1088/1088 [==============================] - 20s 19ms/step - loss: 0.2051 - accuracy: 0.9367 - val_loss: 0.0385 - val_accuracy: 0.9864
# Epoch 11/20
# 1088/1088 [==============================] - 20s 19ms/step - loss: 0.1986 - accuracy: 0.9415 - val_loss: 0.0467 - val_accuracy: 0.9823
# Epoch 12/20
# 1088/1088 [==============================] - 20s 19ms/step - loss: 0.1798 - accuracy: 0.9438 - val_loss: 0.0383 - val_accuracy: 0.9859
# Epoch 13/20
# 1088/1088 [==============================] - 21s 19ms/step - loss: 0.1745 - accuracy: 0.9465 - val_loss: 0.0454 - val_accuracy: 0.9868
# Epoch 14/20
# 1088/1088 [==============================] - 20s 18ms/step - loss: 0.1738 - accuracy: 0.9477 - val_loss: 0.0203 - val_accuracy: 0.9943
# Epoch 15/20
# 1088/1088 [==============================] - 20s 18ms/step - loss: 0.1749 - accuracy: 0.9475 - val_loss: 0.0226 - val_accuracy: 0.9930
# Epoch 16/20
# 1088/1088 [==============================] - 20s 18ms/step - loss: 0.1683 - accuracy: 0.9503 - val_loss: 0.0320 - val_accuracy: 0.9864
# Epoch 17/20
# 1088/1088 [==============================] - 20s 18ms/step - loss: 0.1594 - accuracy: 0.9522 - val_loss: 0.0240 - val_accuracy: 0.9930
# Epoch 18/20
# 1088/1088 [==============================] - 20s 18ms/step - loss: 0.1620 - accuracy: 0.9524 - val_loss: 0.0223 - val_accuracy: 0.9934
# Epoch 19/20
# 1088/1088 [==============================] - 20s 18ms/step - loss: 0.1607 - accuracy: 0.9527 - val_loss: 0.0183 - val_accuracy: 0.9948
# Epoch 20/20
# 1088/1088 [==============================] - 22s 20ms/step - loss: 0.1435 - accuracy: 0.9566 - val_loss: 0.0387 - val_accuracy: 0.9893

# %%
score = model.evaluate(X_test_gray_norm, y_test)
print('Test Accuracy: {}'.format(score[1]))
# Out:
# 395/395 [==============================] - 2s 5ms/step - loss: 0.0714 - accuracy: 0.9820
# Test Accuracy: 0.9820269346237183

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #BEST ACCURACY OBTAINED OF 98.20 when data augmentation is applied
