# %% [markdown]
# # TASK #2: MOUNT DRIVE AND IMPORT LIBRARIES/DATASETS

# %% [markdown]
# - In this case study, we want to classify images of traffic signs using deep Convolutional Neural Networks (CNNs).
# - The dataset consists of 43 different classes of images.
# - Classes are as listed below:
#   - 0 = Speed limit (20km/h)
#   - 1 = Speed limit (30km/h)
#   - 2 = Speed limit (50km/h)
#   - 3 = Speed limit (60km/h)
#   - 4 = Speed limit (70km/h)
#   - 5 = Speed limit (80km/h)
#   - 6 = End of speed limit (80km/h)
#   - 7 = Speed limit (100km/h)
#   - 8 = Speed limit (120km/h)
#   - 9 = No passing
#   - 10 = No passing for vehicles over 3.5 metric tons
#   - 11 = Right-of-way at the next intersection
#   - 12 = Priority road
#   - 13 = Yield
#   - 14 = Stop
#   - 15 = No vehicles
#   - 16 = Vehicles over 3.5 metric tons prohibited
#   - 17 = No entry
#   - 18 = General caution
#   - 19 = Dangerous curve to the left
#   - 20 = Dangerous curve to the right
#   - 21 = Double curve
#   - 22 = Bumpy road
#   - 23 = Slippery road
#   - 24 = Road narrows on the right
#   - 25 = Road work
#   - 26 = Traffic signals
#   - 27 = Pedestrians
#   - 28 = Children crossing
#   - 29 = Bicycles crossing
#   - 30 = Beware of ice/snow
#   - 31 = Wild animals crossing
#   - 32 = End of all speed and passing limits
#   - 33 = Turn right ahead
#   - 34 = Turn left ahead
#   - 35 = Ahead only
#   - 36 = Go straight or right
#   - 37 = Go straight or left
#   - 38 = Keep right
#   - 39 = Keep left
#   - 40 = Roundabout mandatory
#   - 41 = End of no passing
#   - 42 = End of no passing by vehicles over 3.5 metric tons
#
# - Citation
# J. Stallkamp, M. Schlipsing, J. Salmen, and C. Igel. The German Traffic Sign Recognition Benchmark: A multi-class classification competition. In Proceedings of the IEEE International Joint Conference on Neural Networks, pages 1453–1460. 2011.
# @inproceedings{Stallkamp-IJCNN-2011, author = {Johannes Stallkamp and Marc Schlipsing and Jan Salmen and Christian Igel}, booktitle = {IEEE International Joint Conference on Neural Networks}, title = {The {G}erman {T}raffic {S}ign {R}ecognition {B}enchmark: A multi-class classification competition}, year = {2011}, pages = {1453--1460} }

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import pandas as pd
import seaborn as sns
import pickle
import random
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq" -O train.p && rm -rf /tmp/cookies.txt
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1zJxB1YzBYuImaHBSxWGN-ZXPDRYN_CTX' -O valid.p
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1jZhZpEZkYFaaPPAwfd1cB8e-FK0aoeC0' -O test.p
# Out:
# --2020-09-29 09:21:20--  https://docs.google.com/uc?export=download&confirm=Pb6o&id=1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq
# Resolving docs.google.com (docs.google.com)... 108.177.119.113, 108.177.119.139, 108.177.119.101, ...
# Connecting to docs.google.com (docs.google.com)|108.177.119.113|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-00-4o-docs.googleusercontent.com/docs/securesc/usblr9kquiq6svlfo0pkefm2gqlufd1l/4ifvk09n1jlati1hmatehuv2psamhl9n/1601371275000/17242455652310080862/10433750111559228706Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e=download [following]
# --2020-09-29 09:21:20--  https://doc-00-4o-docs.googleusercontent.com/docs/securesc/usblr9kquiq6svlfo0pkefm2gqlufd1l/4ifvk09n1jlati1hmatehuv2psamhl9n/1601371275000/17242455652310080862/10433750111559228706Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e=download
# Resolving doc-00-4o-docs.googleusercontent.com (doc-00-4o-docs.googleusercontent.com)... 173.194.79.132, 2a00:1450:4013:c05::84
# Connecting to doc-00-4o-docs.googleusercontent.com (doc-00-4o-docs.googleusercontent.com)|173.194.79.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=higj66v8cmel6&continue=https://doc-00-4o-docs.googleusercontent.com/docs/securesc/usblr9kquiq6svlfo0pkefm2gqlufd1l/4ifvk09n1jlati1hmatehuv2psamhl9n/1601371275000/17242455652310080862/10433750111559228706Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e%3Ddownload&hash=gmmp3bjmtvbaefa9lqvrf1n66s71rqkp [following]
# --2020-09-29 09:21:20--  https://docs.google.com/nonceSigner?nonce=higj66v8cmel6&continue=https://doc-00-4o-docs.googleusercontent.com/docs/securesc/usblr9kquiq6svlfo0pkefm2gqlufd1l/4ifvk09n1jlati1hmatehuv2psamhl9n/1601371275000/17242455652310080862/10433750111559228706Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e%3Ddownload&hash=gmmp3bjmtvbaefa9lqvrf1n66s71rqkp
# Connecting to docs.google.com (docs.google.com)|108.177.119.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-00-4o-docs.googleusercontent.com/docs/securesc/usblr9kquiq6svlfo0pkefm2gqlufd1l/4ifvk09n1jlati1hmatehuv2psamhl9n/1601371275000/17242455652310080862/10433750111559228706Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e=download&nonce=higj66v8cmel6&user=10433750111559228706Z&hash=0vr3p1f6ncu9o8miidal32lglbrodp0j [following]
# --2020-09-29 09:21:21--  https://doc-00-4o-docs.googleusercontent.com/docs/securesc/usblr9kquiq6svlfo0pkefm2gqlufd1l/4ifvk09n1jlati1hmatehuv2psamhl9n/1601371275000/17242455652310080862/10433750111559228706Z/1tQ2HkQdxCUpAo4twbqN6mu7FYD7Ry5tq?e=download&nonce=higj66v8cmel6&user=10433750111559228706Z&hash=0vr3p1f6ncu9o8miidal32lglbrodp0j
# Connecting to doc-00-4o-docs.googleusercontent.com (doc-00-4o-docs.googleusercontent.com)|173.194.79.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/x-pascal]
# Saving to: ‘train.p’
#
# train.p                 [    <=>             ] 102.18M  78.6MB/s    in 1.3s
#
# 2020-09-29 09:21:22 (78.6 MB/s) - ‘train.p’ saved [107146452]
#
# --2020-09-29 09:21:22--  https://docs.google.com/uc?export=download&id=1zJxB1YzBYuImaHBSxWGN-ZXPDRYN_CTX
# Resolving docs.google.com (docs.google.com)... 108.177.119.139, 108.177.119.113, 108.177.119.100, ...
# Connecting to docs.google.com (docs.google.com)|108.177.119.139|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0c-7s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/ahq9qrhudrmhcsnlmubqkd0cqijn6l2p/1601371275000/17242455652310080862/*/1zJxB1YzBYuImaHBSxWGN-ZXPDRYN_CTX?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2020-09-29 09:21:23--  https://doc-0c-7s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/ahq9qrhudrmhcsnlmubqkd0cqijn6l2p/1601371275000/17242455652310080862/*/1zJxB1YzBYuImaHBSxWGN-ZXPDRYN_CTX?e=download
# Resolving doc-0c-7s-docs.googleusercontent.com (doc-0c-7s-docs.googleusercontent.com)... 173.194.79.132, 2a00:1450:4013:c05::84
# Connecting to doc-0c-7s-docs.googleusercontent.com (doc-0c-7s-docs.googleusercontent.com)|173.194.79.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/x-pascal]
# Saving to: ‘valid.p’
#
# valid.p                 [ <=>                ]  12.95M  --.-KB/s    in 0.1s
#
# 2020-09-29 09:21:23 (99.6 MB/s) - ‘valid.p’ saved [13578712]
#
# --2020-09-29 09:21:23--  https://docs.google.com/uc?export=download&id=1jZhZpEZkYFaaPPAwfd1cB8e-FK0aoeC0
# Resolving docs.google.com (docs.google.com)... 108.177.126.101, 108.177.126.102, 108.177.126.139, ...
# Connecting to docs.google.com (docs.google.com)|108.177.126.101|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0g-7s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/3lilvic2ea4ich9k05rv9sbl87954a1t/1601371275000/17242455652310080862/*/1jZhZpEZkYFaaPPAwfd1cB8e-FK0aoeC0?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2020-09-29 09:21:25--  https://doc-0g-7s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/3lilvic2ea4ich9k05rv9sbl87954a1t/1601371275000/17242455652310080862/*/1jZhZpEZkYFaaPPAwfd1cB8e-FK0aoeC0?e=download
# Resolving doc-0g-7s-docs.googleusercontent.com (doc-0g-7s-docs.googleusercontent.com)... 173.194.79.132, 2a00:1450:4013:c05::84
# Connecting to doc-0g-7s-docs.googleusercontent.com (doc-0g-7s-docs.googleusercontent.com)|173.194.79.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/x-pascal]
# Saving to: ‘test.p’
#
# test.p                  [   <=>              ]  37.09M  79.4MB/s    in 0.5s
#
# 2020-09-29 09:21:26 (79.4 MB/s) - ‘test.p’ saved [38888118]

# %%
with open("/content/train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("/content/valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("/content/test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']
X_validation, y_validation = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %% [markdown]
# TRAINING DATASET SHAPE

# %%
X_train.shape, y_train.shape
# Out:
# ((34799, 32, 32, 3), (34799,))

# %% [markdown]
# VALIDATION DATSET SHAPE

# %%
X_validation.shape, y_validation.shape
# Out:
# ((4410, 32, 32, 3), (4410,))

# %% [markdown]
# TESTING DATASET SHAPE

# %%
X_test.shape, y_test.shape
# Out:
# ((12630, 32, 32, 3), (12630,))

# %% [markdown]
# PRINTING THE LABELS

# %%
y_train

#### WE FIND THAT THE LABELS ARE ALREADY IN NUMERICAL FORMAT
# Out:
# array([41, 41, 41, ..., 25, 25, 25], dtype=uint8)

# %% [markdown]
# # TASK #3: PERFROM IMAGES VISUALIZATION

# %%
i = np.random.randint(1, len(X_train))
plt.imshow(X_train[i])
y_train[i]
# Out:
# 3

# %%
# Let's view more images in a grid format
# Define the dimensions of the plot grid 
W_grid = 5
L_grid = 5

# fig, axes = plt.subplots(L_grid, W_grid)
# subplot return the figure object and axes object
# we can use the axes object to plot specific figures at various locations

fig, axes = plt.subplots(L_grid, W_grid, figsize = (10,10))

axes = axes.ravel() # flaten the 15 x 15 matrix into 225 array

n_training = len(X_train) # get the length of the training dataset

# Select a random number from 0 to n_training
for i in np.arange(0, W_grid * L_grid): # create evenly spaces variables 

    # Select a random number
    index = np.random.randint(0, n_training)
    # read and display an image with the selected index    
    axes[i].imshow( X_train[index])
    axes[i].set_title(y_train[index], fontsize = 15)
    axes[i].axis('off')

plt.subplots_adjust(hspace=0.4)

# %% [markdown]
# # TASK #4: CONVERT IMAGES TO GRAYSCALE AND PERFORM NORMALIZATION

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %% [markdown]
# #Since its an RGB image, so it means that you have add r with g with b and then divide it by 3 to get your desired grayscale image. Its done in this way. If you have an color image like the image shown above and you want to convert it into grayscale using average method.

# %%
X_train_gray = np.sum(X_train/3, axis = 3, keepdims = True)
X_test_gray = np.sum(X_test/3, axis = 3, keepdims = True)
X_validation_gray = np.sum(X_validation/3, axis = 3, keepdims = True)

# %%
X_train_gray.shape
# Out:
# (34799, 32, 32, 1)

# %%
X_test_gray.shape
# Out:
# (12630, 32, 32, 1)

# %%
X_validation_gray.shape
# Out:
# (4410, 32, 32, 1)

# %%
X_train_gray_norm = (X_train_gray - 128)/128
X_test_gray_norm = (X_test_gray - 128)/128
X_validation_gray_norm = (X_validation_gray - 128)/128

# %%
i = random.randint(1, len(X_train_gray))
plt.imshow(X_train_gray[i].squeeze(), cmap = 'gray')
plt.figure()
plt.imshow(X_train[i])
plt.figure()
plt.imshow(X_train_gray_norm[i].squeeze(), cmap = 'gray')

# %% [markdown]
# #Building the model

# %% [markdown]
# #Use this space for coding

# %% [markdown]
# NEW TRAINING DATASET SHAPE

# %%
X_train_gray_norm.shape, y_train.shape
# Out:
# ((34799, 32, 32, 1), (34799,))

# %% [markdown]
# NEW TESTING DATASET SHAPE

# %%
X_test_gray_norm.shape, y_test.shape
# Out:
# ((12630, 32, 32, 1), (12630,))

# %% [markdown]
# NEW VALIDATION DATASET SHAPE

# %%
X_validation_gray_norm.shape, y_validation.shape
# Out:
# ((4410, 32, 32, 1), (4410,))

# %% [markdown]
# IMPORTING LIBRARIES TO BUILD A VGG-16 like NETWORK (First 7 blocks of VGG-16)

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Input, Flatten, Dense
from tensorflow.keras.models import Sequential

# %%
CNN = Sequential()
CNN.add(Input((32, 32, 1)))

CNN.add(Conv2D(16, (3,3), strides=1, padding='same', kernel_initializer='he_normal', activation='relu'))
CNN.add(BatchNormalization(axis=3))
CNN.add(Conv2D(16, (3,3), strides=1, padding='same', kernel_initializer='he_normal', activation='relu'))
CNN.add(BatchNormalization(axis=3))
CNN.add(MaxPooling2D((2,2), strides=2))

CNN.add(Conv2D(32, (3,3), strides=1, padding='same', kernel_initializer='he_normal', activation='relu'))
CNN.add(BatchNormalization(axis=3))
CNN.add(Conv2D(32, (3,3), strides=1, padding='same', kernel_initializer='he_normal', activation='relu'))
CNN.add(BatchNormalization(axis=3))
CNN.add(MaxPooling2D((2,2), strides=2))

CNN.add(Conv2D(64, (3,3), strides=1, padding='same', kernel_initializer='he_normal', activation='relu'))
CNN.add(BatchNormalization(axis=3))
CNN.add(Conv2D(64, (3,3), strides=1, padding='same', kernel_initializer='he_normal', activation='relu'))
CNN.add(BatchNormalization(axis=3))
CNN.add(MaxPooling2D((2,2), strides=2))

CNN.add(Flatten())
CNN.add(Dense(512, activation='relu', kernel_initializer='he_normal'))
CNN.add(Dense(128, activation='relu', kernel_initializer='he_normal'))
CNN.add(Dense(43, activation='softmax'))

# %%
CNN.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 16)        160
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 16)        64
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        2320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 16)        64
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        4640
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 32)        128
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 32)        9248
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 64)          18496
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 64)          256
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 64)          256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               524800
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_2 (Dense)              (None, 43)                5547
# =================================================================
# Total params: 668,699
# Trainable params: 668,251
# Non-trainable params: 448
# _________________________________________________________________

# %%
CNN.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = CNN.fit(X_train_gray_norm, y_train, validation_data=(X_validation_gray_norm, y_validation), epochs=30, batch_size=64)
# Out:
# Epoch 1/30
# 544/544 [==============================] - 3s 6ms/step - loss: 0.7430 - accuracy: 0.7959 - val_loss: 0.5354 - val_accuracy: 0.8592
# Epoch 2/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0600 - accuracy: 0.9812 - val_loss: 0.3826 - val_accuracy: 0.9039
# Epoch 3/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0315 - accuracy: 0.9902 - val_loss: 0.4470 - val_accuracy: 0.8859
# Epoch 4/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0315 - accuracy: 0.9902 - val_loss: 0.3581 - val_accuracy: 0.9200
# Epoch 5/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0281 - accuracy: 0.9910 - val_loss: 0.3365 - val_accuracy: 0.9215
# Epoch 6/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0271 - accuracy: 0.9914 - val_loss: 0.3293 - val_accuracy: 0.9370
# Epoch 7/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0170 - accuracy: 0.9947 - val_loss: 0.1872 - val_accuracy: 0.9558
# Epoch 8/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0109 - accuracy: 0.9966 - val_loss: 0.3679 - val_accuracy: 0.9327
# Epoch 9/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0304 - accuracy: 0.9917 - val_loss: 0.3173 - val_accuracy: 0.9333
# Epoch 10/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0133 - accuracy: 0.9963 - val_loss: 0.2456 - val_accuracy: 0.9451
# Epoch 11/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0117 - accuracy: 0.9968 - val_loss: 0.3189 - val_accuracy: 0.9460
# Epoch 12/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0189 - accuracy: 0.9944 - val_loss: 0.3727 - val_accuracy: 0.9379
# Epoch 13/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0107 - accuracy: 0.9972 - val_loss: 0.2958 - val_accuracy: 0.9454
# Epoch 14/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0156 - accuracy: 0.9958 - val_loss: 0.2677 - val_accuracy: 0.9542
# Epoch 15/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0125 - accuracy: 0.9966 - val_loss: 0.2153 - val_accuracy: 0.9660
# Epoch 16/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0101 - accuracy: 0.9973 - val_loss: 0.2213 - val_accuracy: 0.9585
# Epoch 17/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0096 - accuracy: 0.9974 - val_loss: 0.2396 - val_accuracy: 0.9562
# Epoch 18/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0179 - accuracy: 0.9953 - val_loss: 0.3582 - val_accuracy: 0.9483
# Epoch 19/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0078 - accuracy: 0.9976 - val_loss: 0.2371 - val_accuracy: 0.9655
# Epoch 20/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0074 - accuracy: 0.9976 - val_loss: 0.3010 - val_accuracy: 0.9558
# Epoch 21/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0125 - accuracy: 0.9965 - val_loss: 0.2948 - val_accuracy: 0.9553
# Epoch 22/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0078 - accuracy: 0.9981 - val_loss: 0.3025 - val_accuracy: 0.9605
# Epoch 23/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0124 - accuracy: 0.9972 - val_loss: 0.1842 - val_accuracy: 0.9658
# Epoch 24/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0124 - accuracy: 0.9972 - val_loss: 0.2432 - val_accuracy: 0.9562
# Epoch 25/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0044 - accuracy: 0.9990 - val_loss: 0.4670 - val_accuracy: 0.9476
# Epoch 26/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0109 - accuracy: 0.9976 - val_loss: 0.2764 - val_accuracy: 0.9601
# Epoch 27/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0071 - accuracy: 0.9982 - val_loss: 0.2862 - val_accuracy: 0.9580
# Epoch 28/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0137 - accuracy: 0.9970 - val_loss: 0.4004 - val_accuracy: 0.9506
# Epoch 29/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0126 - accuracy: 0.9973 - val_loss: 0.1998 - val_accuracy: 0.9653
# Epoch 30/30
# 544/544 [==============================] - 3s 5ms/step - loss: 0.0044 - accuracy: 0.9991 - val_loss: 0.2760 - val_accuracy: 0.9585

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Training Loss', 'Validation Loss'], loc='best')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='best')
plt.show()

# %%
predictions = CNN.predict_classes(X_test_gray_norm)
predictions
# Out:
# WARNING:tensorflow:From <ipython-input-29-31aca03e237d>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# array([16,  1, 38, ...,  8,  7, 10])

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

plt.figure(figsize=(25, 25))
cm = confusion_matrix(y_test, predictions)
hm = sns.heatmap(cm, annot=True, square=True, linewidths=1, cmap='Blues')
plt.show(hm)

# %% [markdown]
# EVALUATING THE MODEL'S PERFORMANCE ON THE TESTING DATASET

# %%
print('Testing Accuracy is : {}'.format(CNN.evaluate(X_test_gray_norm, y_test)[1]))
# Out:
# 395/395 [==============================] - 1s 2ms/step - loss: 0.3441 - accuracy: 0.9485
# Testing Accuracy is : 0.9485352039337158

# %% [markdown]
# # TASK #8: ASSESS TRAINED CNN MODEL PERFORMANCE

# %% [markdown]
# #Marks will be given on basis of next code cells results

# %%
score = CNN.evaluate(X_test_gray_norm, y_test)
print('Test Accuracy: {}'.format(score[1]))
# Out:
# 395/395 [==============================] - 1s 2ms/step - loss: 0.3441 - accuracy: 0.9485
# Test Accuracy: 0.9485352039337158

# %% [markdown]
# #Attach a screen shot of your results as proof below this cell

# %% [markdown]
# ![Test M2.PNG](data:image/png;base64,...)

# %% [markdown]
# #Other helper functions

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'bo', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# %%
plt.plot(epochs, loss, 'ro', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()

# %%
predicted_classes = CNN.predict_classes(X_test_gray_norm)
y_true = y_test

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, predicted_classes)
plt.figure(figsize = (25, 25))
sns.heatmap(cm, annot = True)

# %%
L = 5
W = 5

fig, axes = plt.subplots(L, W, figsize = (12, 12))
axes = axes.ravel()

for i in np.arange(0, L*W):
    axes[i].imshow(X_test[i])
    axes[i].set_title('Prediction = {}\n True = {}'.format(predicted_classes[i], y_true[i]))
    axes[i].axis('off')

plt.subplots_adjust(wspace = 1)
